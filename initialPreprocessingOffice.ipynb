# %% [markdown]
# # Final Project - The Office

# %%
import requests
import os
from bs4 import BeautifulSoup

# %% [markdown]
# PAGE 1

# %%
# Function to sanitize episode titles for use as filenames
def sanitize_filename(title):
    invalid_chars = ['<', '>', ':', '"', '/', '\\', '|', '?', '*', '&']
    for char in invalid_chars:
        title = title.replace(char, '_')
    return title

# Create a new directory for the episode transcripts
folder_name = 'episode_transcripts'
os.makedirs(folder_name, exist_ok=True)

# The main URL of the page with links to transcripts
main_url = 'https://transcripts.foreverdreaming.org/viewforum.php?f=574'

# Send a GET request to the main page
main_response = requests.get(main_url)

# Check if the main page request was successful
if main_response.status_code == 200:
    # Parse the HTML content of the main page
    main_soup = BeautifulSoup(main_response.content, 'html.parser')
    
    # Find the elements containing links to the transcripts
    links = main_soup.find_all('a', class_='topictitle')

    # Loop through all found links and fetch each transcript
    for index, link in enumerate(links):
        episode_title_raw = link.get_text(strip=True)
        episode_title = sanitize_filename(episode_title_raw)
        episode_url = 'https://transcripts.foreverdreaming.org' + link['href']
        episode_response = requests.get(episode_url)
        
        if episode_response.status_code == 200:
            episode_soup = BeautifulSoup(episode_response.content, 'html.parser')
            transcript_elements = episode_soup.find_all('div', class_='postbody')
            
            if transcript_elements:
                # Skip the first transcript element if it's the announcements
                start_index = 1 if index == 0 else 0
                for element in transcript_elements[start_index:]:
                    transcript_text = element.get_text(strip=True)
                    filename = os.path.join(folder_name, f'{episode_title}.txt')
                    
                    # Write the transcript text to a .txt file
                    with open(filename, 'w', encoding='utf-8') as file:
                        file.write(transcript_text)
                        print(f"Saved transcript to {filename}")
            else:
                print(f"No transcript elements found for {episode_title}")
        else:
            print(f"Failed to retrieve transcript page for {episode_title}")
else:
    print("Failed to retrieve the main page")
# Out:
# Saved transcript to episode_transcripts\09x26 - Retrospective.txt
# Saved transcript to episode_transcripts\09x24_25 - Finale.txt
# Saved transcript to episode_transcripts\09x22_23 - A.A.R.M.txt
# Saved transcript to episode_transcripts\09x21 - Livin' the Dream.txt
# Saved transcript to episode_transcripts\09x20 - Paper Airplane.txt
# Saved transcript to episode_transcripts\09x19 - Stairmageddon.txt
# Saved transcript to episode_transcripts\09x18 - Promos.txt
# Saved transcript to episode_transcripts\09x17 - The Farm.txt
# Saved transcript to episode_transcripts\09x16 - Moving On.txt
# Saved transcript to episode_transcripts\09x15 - Couples Discount.txt
# Saved transcript to episode_transcripts\09x14 - Vandalism.txt
# Saved transcript to episode_transcripts\09x13 - Junior Salesman.txt
# Saved transcript to episode_transcripts\09x12 - Customer Loyalty.txt
# Saved transcript to episode_transcripts\09x11 - Suit Warehouse.txt
# Saved transcript to episode_transcripts\09x10 - Lice.txt
# Saved transcript to episode_transcripts\09x09 - Dwight Christmas.txt
# Saved transcript to episode_transcripts\09x08 - The Target.txt
# Saved transcript to episode_transcripts\09x07 - The Whale.txt
# Saved transcript to episode_transcripts\09x06 - The Boat.txt
# Saved transcript to episode_transcripts\09x05 - Here Comes Treble.txt
# Saved transcript to episode_transcripts\09x04 - Work Bus.txt
# Saved transcript to episode_transcripts\09x03 - Andy's Ancestry.txt
# Saved transcript to episode_transcripts\09x02 - Roy's Wedding.txt
# Saved transcript to episode_transcripts\09x01 - The New Guys.txt
# Saved transcript to episode_transcripts\08x99 - Deleted Scenes from Season 8.txt
# Saved transcript to episode_transcripts\08x24 - Free Family Portrait Studio.txt
# Saved transcript to episode_transcripts\08x23 - Turf w_r.txt
# Saved transcript to episode_transcripts\08x22 - Fundraiser.txt
# Saved transcript to episode_transcripts\08x21 - Angry Andy.txt
# Saved transcript to episode_transcripts\08x20 - Welcome Party.txt
# Saved transcript to episode_transcripts\08x19 - Get The Girl.txt
# Saved transcript to episode_transcripts\08x18 - Last Day In Florida.txt
# Saved transcript to episode_transcripts\08x17 - Test The Store.txt
# Saved transcript to episode_transcripts\08x16 - After Hours.txt
# Saved transcript to episode_transcripts\08x15 - Tallahassee.txt
# Saved transcript to episode_transcripts\08x14 - Special Project.txt
# Saved transcript to episode_transcripts\08x13 - Jury Duty.txt
# Saved transcript to episode_transcripts\08x12 - Pool Party.txt
# Saved transcript to episode_transcripts\08x11 - Trivia.txt
# Saved transcript to episode_transcripts\08x10 - Christmas Wishes.txt
# Saved transcript to episode_transcripts\08x09 - Mrs. California.txt
# Saved transcript to episode_transcripts\08x08 - Gettysburg.txt
# Saved transcript to episode_transcripts\08x07 - Pam's Replacement.txt
# Saved transcript to episode_transcripts\08x06 - Doomsday.txt
# Saved transcript to episode_transcripts\08x05 - Spooked.txt
# Saved transcript to episode_transcripts\08x04 - Garden Party.txt
# Saved transcript to episode_transcripts\08x03 - Lotto.txt
# Saved transcript to episode_transcripts\08x02 - The Incentive.txt
# Saved transcript to episode_transcripts\08x01 - The List.txt
# Saved transcript to episode_transcripts\07x25_26 - Search Committee (Parts 1_2).txt
# Saved transcript to episode_transcripts\07x24 - Dwight K. Schrute, (Acting) Manager.txt
# Saved transcript to episode_transcripts\07x23 - The Inner Circle.txt
# Saved transcript to episode_transcripts\07x22 - Goodbye, Michael.txt
# Saved transcript to episode_transcripts\07x21 - Michael's Last Dundies.txt
# Saved transcript to episode_transcripts\07x20 - Training Day.txt
# Saved transcript to episode_transcripts\07x19 - Garage Sale.txt
# Saved transcript to episode_transcripts\07x18 - Todd Packer.txt
# Saved transcript to episode_transcripts\07x17 - thr_at Level Midnight.txt
# Saved transcript to episode_transcripts\07x16 - PDA.txt
# Saved transcript to episode_transcripts\07x15 - The Search.txt
# Saved transcript to episode_transcripts\07x14 - The Seminar.txt
# Saved transcript to episode_transcripts\07x13 - Ultimatum.txt
# Saved transcript to episode_transcripts\07x11_12 - Classy Christmas (Parts 1_2).txt
# Saved transcript to episode_transcripts\07x10 - China.txt
# Saved transcript to episode_transcripts\07x09 - WUPHF.com.txt
# Saved transcript to episode_transcripts\07x08 - Viewing Party.txt
# Saved transcript to episode_transcripts\07x07 - Christening.txt
# Saved transcript to episode_transcripts\07x00 - The 3rd Floor Webisodes 1-3.txt
# Saved transcript to episode_transcripts\07x06 - Costume Contest.txt
# Saved transcript to episode_transcripts\07x05 - The Sting.txt
# Saved transcript to episode_transcripts\07x04 - Sex Ed.txt
# Saved transcript to episode_transcripts\07x03 - Andy's Play.txt
# Saved transcript to episode_transcripts\07x02 - Counseling.txt
# Saved transcript to episode_transcripts\07x01 - Nepotism.txt
# Saved transcript to episode_transcripts\06x26 - Whistleblower.txt
# Saved transcript to episode_transcripts\06x25 - The Chump.txt
# Saved transcript to episode_transcripts\06x24 - The Cover-Up.txt
# Saved transcript to episode_transcripts\06x23 - Body Language.txt

# %% [markdown]
# PAGE 2

# %%
# Function to sanitize episode titles for use as filenames
def sanitize_filename(title):
    invalid_chars = ['<', '>', ':', '"', '/', '\\', '|', '?', '*', '&']
    for char in invalid_chars:
        title = title.replace(char, '_')
    return title

# Create a new directory for the episode transcripts with a different name
folder_name = 'episode_transcripts_pt2'
os.makedirs(folder_name, exist_ok=True)

# The main URL of the page with links to transcripts
main_url = 'https://transcripts.foreverdreaming.org/viewforum.php?f=574&start=78'

# Send a GET request to the main page
main_response = requests.get(main_url)

# Check if the main page request was successful
if main_response.status_code == 200:
    # Parse the HTML content of the main page
    main_soup = BeautifulSoup(main_response.content, 'html.parser')
    
    # Find the elements containing links to the transcripts
    links = main_soup.find_all('a', class_='topictitle')

    # Loop through all found links and fetch each transcript
    for link in links:
        episode_title_raw = link.get_text(strip=True)
        episode_title = sanitize_filename(episode_title_raw)
        episode_url = 'https://transcripts.foreverdreaming.org' + link['href']
        episode_response = requests.get(episode_url)
        
        if episode_response.status_code == 200:
            episode_soup = BeautifulSoup(episode_response.content, 'html.parser')
            transcript_elements = episode_soup.find_all('div', class_='postbody')
            
            for element in transcript_elements:
                transcript_text = element.get_text(strip=True)
                filename = os.path.join(folder_name, f'{episode_title}.txt')
                
                # Write the transcript text to a .txt file
                with open(filename, 'w', encoding='utf-8') as file:
                    file.write(transcript_text)
                    print(f"Saved transcript to {filename}")
        else:
            print(f"Failed to retrieve transcript page for {episode_title}")
else:
    print("Failed to retrieve the main page")
# Out:
# Saved transcript to episode_transcripts_pt2\Updates_ (01_23_23) Secrets of the Board.txt
# Saved transcript to episode_transcripts_pt2\06x22 - Secretary's Day.txt
# Saved transcript to episode_transcripts_pt2\06x21 - Happy Hour.txt
# Saved transcript to episode_transcripts_pt2\06x20 - New Leads.txt
# Saved transcript to episode_transcripts_pt2\06x19 - St. Patrick's Day.txt
# Saved transcript to episode_transcripts_pt2\06x17_18 - The Delivery (Parts 1_2).txt
# Saved transcript to episode_transcripts_pt2\06x16 - The Manager and the Salesman.txt
# Saved transcript to episode_transcripts_pt2\06x15 - Sabre.txt
# Saved transcript to episode_transcripts_pt2\06x14 - The Banker.txt
# Saved transcript to episode_transcripts_pt2\06x13 - Secret Santa.txt
# Saved transcript to episode_transcripts_pt2\06x12 - Scott's Tots.txt
# Saved transcript to episode_transcripts_pt2\06x11 - Shareholder Meeting.txt
# Saved transcript to episode_transcripts_pt2\06x10 - m_rder.txt
# Saved transcript to episode_transcripts_pt2\06x09 - Double Date.txt
# Saved transcript to episode_transcripts_pt2\06x00 - Subtle Sexuality Webisodes 1-3.txt
# Saved transcript to episode_transcripts_pt2\06x08 - Koi Pond.txt
# Saved transcript to episode_transcripts_pt2\06x07 - The Lover.txt
# Saved transcript to episode_transcripts_pt2\06x06 - Mafia.txt
# Saved transcript to episode_transcripts_pt2\06x04_05 - Niagara (Parts 1_2).txt
# Saved transcript to episode_transcripts_pt2\06x03 - The Promotion.txt
# Saved transcript to episode_transcripts_pt2\06x02 - The Meeting.txt
# Saved transcript to episode_transcripts_pt2\05x99 - Deleted Scenes from Season 5.txt
# Saved transcript to episode_transcripts_pt2\06x01 - Gossip.txt
# Saved transcript to episode_transcripts_pt2\05x30 - Gag Reel.txt
# Saved transcript to episode_transcripts_pt2\05x29 - 100 Episodes 100 Moments.txt
# Saved transcript to episode_transcripts_pt2\05x28 - Company Picnic.txt
# Saved transcript to episode_transcripts_pt2\05x27 - Cafe Disco.txt
# Saved transcript to episode_transcripts_pt2\05x26 - Casual Friday.txt
# Saved transcript to episode_transcripts_pt2\05x25 - Broke.txt
# Saved transcript to episode_transcripts_pt2\05x24 - Heavy Competition.txt
# Saved transcript to episode_transcripts_pt2\05x22 - Dream Team.txt
# Saved transcript to episode_transcripts_pt2\05x23 - The Michael Scott Paper Company.txt
# Saved transcript to episode_transcripts_pt2\05x21 - Two Weeks.txt
# Saved transcript to episode_transcripts_pt2\05x20 - New Boss.txt
# Saved transcript to episode_transcripts_pt2\05x19 - Golden Ticket.txt
# Saved transcript to episode_transcripts_pt2\05x18 - Blood Drive.txt
# Saved transcript to episode_transcripts_pt2\05x17 - Lecture Circuit (Part 2).txt
# Saved transcript to episode_transcripts_pt2\05x16 - Lecture Circuit (Part 1).txt
# Saved transcript to episode_transcripts_pt2\05x14_15 - Stress Relief (Parts 1_2).txt
# Saved transcript to episode_transcripts_pt2\05x13 - Prince Family Paper.txt
# Saved transcript to episode_transcripts_pt2\05x12 - The Duel.txt
# Saved transcript to episode_transcripts_pt2\05x11 - Moroccan Christmas.txt
# Saved transcript to episode_transcripts_pt2\05x10 - The Surplus.txt
# Saved transcript to episode_transcripts_pt2\05x09 - Frame Toby.txt
# Saved transcript to episode_transcripts_pt2\05x08 - Business Trip.txt
# Saved transcript to episode_transcripts_pt2\05x07 - Customer Survey.txt
# Saved transcript to episode_transcripts_pt2\05x06 - Employee Transfer.txt
# Saved transcript to episode_transcripts_pt2\05x05 - Crime Aid.txt
# Saved transcript to episode_transcripts_pt2\05x04 - Baby Shower.txt
# Saved transcript to episode_transcripts_pt2\05x03 - Business Ethics.txt
# Saved transcript to episode_transcripts_pt2\05x01_02 - Weight Loss (Parts 1_2).txt
# Saved transcript to episode_transcripts_pt2\05x00 - Kevin's Loan Webisodes 1-4.txt
# Saved transcript to episode_transcripts_pt2\04x99 - Deleted Scenes from Season 4.txt
# Saved transcript to episode_transcripts_pt2\04x18_19 - Goodbye, Toby (Parts 1_2).txt
# Saved transcript to episode_transcripts_pt2\04x17 - Job Fair.txt
# Saved transcript to episode_transcripts_pt2\04x16 - Did I Stutter_.txt
# Saved transcript to episode_transcripts_pt2\04x15 - Night Out.txt
# Saved transcript to episode_transcripts_pt2\04x14 - Chair Model.txt
# Saved transcript to episode_transcripts_pt2\04x13 - Dinner Party.txt
# Saved transcript to episode_transcripts_pt2\04x12 - The Deposition.txt
# Saved transcript to episode_transcripts_pt2\04x11 - Survivor Man.txt
# Saved transcript to episode_transcripts_pt2\04x10 - Branch Wars.txt
# Saved transcript to episode_transcripts_pt2\04x09 - Local Ad.txt
# Saved transcript to episode_transcripts_pt2\04x07_08 - Money (Parts 1_2).txt
# Saved transcript to episode_transcripts_pt2\04x05_06 - Launch Party (Parts 1_2).txt
# Saved transcript to episode_transcripts_pt2\04x03_04 - Dunder Mifflin Infinity (Parts 1_2).txt
# Saved transcript to episode_transcripts_pt2\04x01_02 - Fun Run (Parts 1_2).txt
# Saved transcript to episode_transcripts_pt2\03x99 - Deleted Scenes from Season 3.txt
# Saved transcript to episode_transcripts_pt2\03x24_25 - The Job (Parts 1_2).txt
# Saved transcript to episode_transcripts_pt2\03x23 - Beach Games.txt
# Saved transcript to episode_transcripts_pt2\03x22 - Women's Appreciation.txt
# Saved transcript to episode_transcripts_pt2\03x21 - Product Recall.txt
# Saved transcript to episode_transcripts_pt2\03x20 - Safety Training.txt
# Saved transcript to episode_transcripts_pt2\03x19 - The Negotiation.txt
# Saved transcript to episode_transcripts_pt2\03x18 - Cocktails.txt
# Saved transcript to episode_transcripts_pt2\03x17 - Business School.txt
# Saved transcript to episode_transcripts_pt2\03x16 - Phyllis' Wedding.txt
# Saved transcript to episode_transcripts_pt2\03x15 - Ben Franklin.txt
# Saved transcript to episode_transcripts_pt2\03x14 - The Return.txt

# %% [markdown]
# PAGE 3

# %%
# Function to sanitize episode titles for use as filenames
def sanitize_filename(title):
    invalid_chars = ['<', '>', ':', '"', '/', '\\', '|', '?', '*', '&']
    for char in invalid_chars:
        title = title.replace(char, '_')
    return title

# Create a new directory for the episode transcripts with a unique name
folder_name = 'episode_transcripts_pt3'
os.makedirs(folder_name, exist_ok=True)

# The main URL of the page with links to transcripts
main_url = 'https://transcripts.foreverdreaming.org/viewforum.php?f=574&start=156'

# Send a GET request to the main page
main_response = requests.get(main_url)

# Check if the main page request was successful
if main_response.status_code == 200:
    # Parse the HTML content of the main page
    main_soup = BeautifulSoup(main_response.content, 'html.parser')
    
    # Find the elements containing links to the transcripts
    links = main_soup.find_all('a', class_='topictitle')

    # Loop through all found links and fetch each transcript
    for link in links:
        episode_title_raw = link.get_text(strip=True)
        episode_title = sanitize_filename(episode_title_raw)
        episode_url = 'https://transcripts.foreverdreaming.org' + link['href']
        episode_response = requests.get(episode_url)
        
        if episode_response.status_code == 200:
            episode_soup = BeautifulSoup(episode_response.content, 'html.parser')
            transcript_elements = episode_soup.find_all('div', class_='postbody')
            
            for element in transcript_elements:
                transcript_text = element.get_text(strip=True)
                filename = os.path.join(folder_name, f'{episode_title}.txt')
                
                # Write the transcript text to a .txt file
                with open(filename, 'w', encoding='utf-8') as file:
                    file.write(transcript_text)
                    print(f"Saved transcript to {filename}")
        else:
            print(f"Failed to retrieve transcript page for {episode_title}")
else:
    print("Failed to retrieve the main page")
# Out:
# Saved transcript to episode_transcripts_pt3\Updates_ (01_23_23) Secrets of the Board.txt
# Saved transcript to episode_transcripts_pt3\03x13 - Traveling Salesmen.txt
# Saved transcript to episode_transcripts_pt3\03x12 - Back from Vacation.txt
# Saved transcript to episode_transcripts_pt3\03x10_11 - A Benihana Christmas (Parts 1_2).txt
# Saved transcript to episode_transcripts_pt3\03x09 - The Convict.txt
# Saved transcript to episode_transcripts_pt3\03x08 - The Merger.txt
# Saved transcript to episode_transcripts_pt3\03x07 - Branch Closing.txt
# Saved transcript to episode_transcripts_pt3\03x06 - Diwali.txt
# Saved transcript to episode_transcripts_pt3\03x05 - Initiation.txt
# Saved transcript to episode_transcripts_pt3\03x04 - Grief Counseling.txt
# Saved transcript to episode_transcripts_pt3\03x03 - The Coup.txt
# Saved transcript to episode_transcripts_pt3\03x02 - The Convention.txt
# Saved transcript to episode_transcripts_pt3\03x01 - Gay Witch Hunt.txt
# Saved transcript to episode_transcripts_pt3\03x00 - The Accountants Webisodes 1-10.txt
# Saved transcript to episode_transcripts_pt3\02x99 - Deleted Scenes from Season 2.txt
# Saved transcript to episode_transcripts_pt3\02x22 - Casino Night.txt
# Saved transcript to episode_transcripts_pt3\02x21 - Conflict Resolution.txt
# Saved transcript to episode_transcripts_pt3\02x20 - Drug Testing.txt
# Saved transcript to episode_transcripts_pt3\02x19 - Michael's Birthday.txt
# Saved transcript to episode_transcripts_pt3\02x18 - Take Your Daughter to Work Day.txt
# Saved transcript to episode_transcripts_pt3\02x17 - Dwight's Speech.txt
# Saved transcript to episode_transcripts_pt3\02x16 - Valentine's Day.txt
# Saved transcript to episode_transcripts_pt3\02x15 - Boys _ Girls.txt
# Saved transcript to episode_transcripts_pt3\02x14 - The Carpet.txt
# Saved transcript to episode_transcripts_pt3\02x13 - The Secret.txt
# Saved transcript to episode_transcripts_pt3\02x12 - The Injury.txt
# Saved transcript to episode_transcripts_pt3\02x11 - Booze Cruise.txt
# Saved transcript to episode_transcripts_pt3\02x10 - Christmas Party.txt
# Saved transcript to episode_transcripts_pt3\02x09 - E-Mail Surveillance.txt
# Saved transcript to episode_transcripts_pt3\02x08 - Performance Review.txt
# Saved transcript to episode_transcripts_pt3\02x07 - The Client.txt
# Saved transcript to episode_transcripts_pt3\02x06 - The Fight.txt
# Saved transcript to episode_transcripts_pt3\02x05 - Halloween.txt
# Saved transcript to episode_transcripts_pt3\02x04 - The f_re.txt
# Saved transcript to episode_transcripts_pt3\02x03 - Office Olympics.txt
# Saved transcript to episode_transcripts_pt3\02x02 - Sexual Harassment.txt
# Saved transcript to episode_transcripts_pt3\02x01 - The Dundies.txt
# Saved transcript to episode_transcripts_pt3\01x99 - Deleted Scenes from Season 1.txt
# Saved transcript to episode_transcripts_pt3\01x06 - Hot Girl.txt
# Saved transcript to episode_transcripts_pt3\01x05 - Basketball.txt
# Saved transcript to episode_transcripts_pt3\01x04 - The Alliance.txt
# Saved transcript to episode_transcripts_pt3\01x03 - Health Care.txt
# Saved transcript to episode_transcripts_pt3\01x02 - Diversity Day.txt
# Saved transcript to episode_transcripts_pt3\01x01 - Pilot.txt

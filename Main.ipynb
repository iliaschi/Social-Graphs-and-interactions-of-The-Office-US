# %%
path_txt = "C:/Users/Lado/Google Drive/SocialGraphs/Untitled Folder/episode_transcripts_pt1"

# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Lado/Google Drive/SocialGraphs/Untitled Folder/cast_details.csv')

# Convert 'Episodes_Count' to numeric (in case it's not)
df['Episodes_Count'] = pd.to_numeric(df['Episodes_Count'], errors='coerce')

# Define a function to extract the first name and last name
def split_name(name):
    # Split the name by spaces
    parts = name.split()
    # The first name is the first part
    first_name = parts[0] if parts else ''
    # The last name is the rest of the parts joined, or the second part if there are only two parts
    last_name = ' '.join(parts[1:]) if len(parts) > 2 else parts[1] if len(parts) == 2 else ''
    return first_name, last_name

# Apply the split_name function to the 'Character' column
df['Character_Name'], df['Character_Surname'] = zip(*df['Character'].apply(split_name))

# Display the modified DataFrame
df[['Actor', 'Character_Name', 'Character_Surname', 'Episodes_Count', 'Years']]


# Filter out rows where 'Episodes_Count' is less than 2
df_filtered = df[df['Episodes_Count'] >= 3]
#df_filtered.to_csv('path_to_save_filtered_csv.csv', index=False)
df_filtered
character_names_list = df_filtered['Character_Name'].tolist()

# %%
import os
import re
from collections import defaultdict

# Function to find connections
def find_connections(folder_path, character_names_list):
    # Dictionary to store names and their connections
    connections = defaultdict(list)
    
    # Compile a regular expression pattern to match any name in the list
    names_pattern = re.compile(r'\b(' + '|'.join(map(re.escape, character_names_list)) + r')\b')

    # Iterate over all text files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            file_path = os.path.join(folder_path, filename)

            # Read the file content
            with open(file_path, 'r', encoding='utf-8') as file:
                content = file.read()

                # For each name in the list, find all occurrences and their connections
                for name in character_names_list:
                    # Find all occurrences of the name followed by a colon
                    pattern = rf"{re.escape(name)}:"
                    for match in re.finditer(pattern, content):
                        # Get the rest of the content after the name
                        following_content = content[match.end():]
                        # Find the next three names that are also in the character_names_list
                        following_names = names_pattern.findall(following_content)
                        # Removing the Speakers name
                        filtered_names = [n for n in following_names if n != name]
                        # Get the next three names, including duplicates
                        connections[name].extend(filtered_names[:3])

    return connections

# Example usage
folder_path = "C:/Users/Lado/Google Drive/SocialGraphs/Untitled Folder/episode_transcripts_pt1" # Replace with your folder path
#character_names_list = ["Michael", "Oscar", "Pam"]  # Replace with your actual list of names
connections_dict = find_connections(folder_path, character_names_list)

# Print the resulting dictionary
for name, conns in connections_dict.items():
    print(f"{name}: {conns}")
# Out:
# Dwight: ['Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Oscar', 'Michael', 'Michael', 'Jim', 'Jim', 'Pam', 'Jim', 'Gabe', 'Darryl', 'Gabe', 'Darryl', 'Gabe', 'The', 'Gabe', 'The', 'Gabe', 'The', 'Gabe', 'Gabe', 'Gabe', 'Gabe', 'Darryl', 'Gabe', 'Darryl', 'Michael', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Michael', 'Kelly', 'Michael', 'Michael', 'Michael', 'Michael', 'Donna', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Michael', 'Kelly', 'Michael', 'Donna', 'Kelly', 'Ryan', 'Kelly', 'Kelly', 'Ryan', 'Ryan', 'Ryan', 'Ryan', 'Kelly', 'Kelly', 'Ryan', 'Ryan', 'Kelly', 'Darryl', 'Mose', 'Kelly', 'Gabe', 'Gabe', 'Gabe', 'Darryl', 'Gabe', 'Darryl', 'Gabe', 'Darryl', 'Kelly', 'Gabe', 'Kelly', 'Kelly', 'Gabe', 'Kelly', 'Erin', 'Erin', 'Stanley', 'Erin', 'Stanley', 'Stanley', 'Stanley', 'Stanley', 'Erin', 'Stanley', 'Erin', 'Oscar', 'Oscar', 'Oscar', 'Kelly', 'Kelly', 'Erin', 'Erin', 'Kelly', 'Kelly', 'Gabe', 'Kelly', 'Gabe', 'Pam', 'Gabe', 'Pam', 'Michael', 'Gabe', 'Pam', 'Michael', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Michael', 'Kelly', 'Michael', 'Donna', 'Michael', 'Donna', 'Michael', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Pam', 'Pam', 'Jim', 'Michael', 'Michael', 'Michael', 'Pam', 'Pam', 'Jim', 'Michael', 'Michael', 'Darryl', 'Meredith', 'Pam', 'Michael', 'Pam', 'Andy', 'Michael', 'Andy', 'Michael', 'Donna', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Andy', 'Michael', 'Andy', 'Stanley', 'Andy', 'Stanley', 'Stanley', 'Donna', 'Michael', 'Michael', 'Michael', 'Donna', 'Donna', 'Donna', 'Donna', 'The', 'The', 'Donna', 'Michael', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Donna', 'Michael', 'Michael', 'Donna', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'The', 'The', 'The', 'Michael', 'Toby', 'Michael', 'Michael', 'Creed', 'Oscar', 'Phyllis', 'Phyllis', 'Toby', 'Toby', 'Andy', 'Toby', 'Phyllis', 'Toby', 'Andy', 'Pam', 'Pam', 'Michael', 'Pam', 'Michael', 'Erin', 'Michael', 'Michael', 'Kevin', 'Angela', 'Angela', 'The', 'Angela', 'The', 'Angela', 'The', 'Angela', 'Angela', 'Angela', 'Angela', 'Andy', 'Angela', 'Andy', 'Pam', 'Andy', 'Pam', 'Phyllis', 'Angela', 'Andy', 'Michael', 'Angela', 'Andy', 'Michael', 'Angela', 'Andy', 'Michael', 'Angela', 'Andy', 'Michael', 'Angela', 'Andy', 'Michael', 'Andy', 'Michael', 'Andy', 'Andy', 'Michael', 'Andy', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Andy', 'Angela', 'Andy', 'Michael', 'Creed', 'Michael', 'Michael', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Jim', 'Angela', 'Jim', 'Pam', 'Jim', 'Pam', 'Michael', 'Michael', 'Michael', 'Jo', 'Nick', 'Nick', 'Nick', 'Nick', 'Nick', 'Oscar', 'Oscar', 'The', 'Kevin', 'Kevin', 'Nick', 'Kevin', 'Jo', 'Jo', 'Jo', 'Jo', 'Jo', 'Jo', 'Jo', 'Jo', 'Michael', 'Jo', 'Michael', 'Andy', 'Toby', 'Toby', 'The', 'The', 'Michael', 'Jo', 'Michael', 'Jo', 'Jo', 'Michael', 'Jo', 'Creed', 'Michael', 'Jo', 'Creed', 'Jim', 'Andy', 'Andy', 'David', 'Andy', 'Gabe', 'Nick', 'Ryan', 'Kelly', 'Hank', 'Andy', 'Phyllis', 'Andy', 'Phyllis', 'Phyllis', 'Phyllis', 'Phyllis', 'Stanley', 'Kevin', 'Kevin', 'Jim', 'Kevin', 'Jim', 'Jim', 'Jim', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Oscar', 'The', 'Jim', 'The', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Pam', 'Jim', 'Gabe', 'Gabe', 'Jo', 'Michael', 'Toby', 'Michael', 'Toby', ...
# Jim: ['Michael', 'Dwight', 'Dwight', 'Pam', 'Michael', 'Dwight', 'Michael', 'Dwight', 'Michael', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Donna', 'Pam', 'Donna', 'Donna', 'Donna', 'Michael', 'Donna', 'Michael', 'Donna', 'Michael', 'Donna', 'Angela', 'Donna', 'Donna', 'Michael', 'Michael', 'Michael', 'Donna', 'Michael', 'Michael', 'Michael', 'Donna', 'Michael', 'Donna', 'Michael', 'Pam', 'Michael', 'Pam', 'Michael', 'Pam', 'Pam', 'Pam', 'Michael', 'Donna', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Michael', 'Pam', 'Dwight', 'Kelly', 'Donna', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Donna', 'Michael', 'Donna', 'Oscar', 'Michael', 'Kevin', 'Michael', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Kelly', 'Pam', 'Kelly', 'Ryan', 'Oscar', 'Michael', 'Michael', 'Michael', 'Pam', 'Pam', 'Pam', 'Pam', 'Michael', 'Pam', 'Michael', 'Pam', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Dwight', 'Kelly', 'Michael', 'Oscar', 'Pam', 'Dwight', 'Pam', 'Dwight', 'Pam', 'Dwight', 'Dwight', 'Pam', 'Dwight', 'Dwight', 'Dwight', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Donna', 'Michael', 'Pam', 'Michael', 'Michael', 'Donna', 'Michael', 'Michael', 'Donna', 'Michael', 'Michael', 'Pam', 'Michael', 'Dwight', 'Michael', 'Dwight', 'Pam', 'Pam', 'Pam', 'Pam', 'Creed', 'Creed', 'Pam', 'Andy', 'Michael', 'Michael', 'Dwight', 'Michael', 'Stanley', 'Angela', 'Michael', 'Michael', 'Andy', 'Tom', 'Michael', 'Pam', 'Pam', 'Pam', 'Pam', 'Michael', 'Pam', 'Michael', 'Michael', 'Michael', 'Pam', 'Billy', 'Billy', 'Michael', 'Pam', 'Michael', 'Stanley', 'Phyllis', 'Pam', 'Pam', 'Gabe', 'Gabe', 'Pam', 'Gabe', 'Pam', 'Gabe', 'Pam', 'Pam', 'Gabe', 'Gabe', 'Gabe', 'The', 'Pam', 'Angela', 'Dwight', 'Dwight', 'Michael', 'Pam', 'Michael', 'Pam', 'Michael', 'Andy', 'Pam', 'Pam', 'Darryl', 'Pam', 'Darryl', 'Darryl', 'Darryl', 'Pam', 'Darryl', 'Darryl', 'Pam', 'Pam', 'Michael', 'Michael', 'Angela', 'Michael', 'Angela', 'Phyllis', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Andy', 'Pam', 'Andy', 'Pam', 'Pam', 'Jo', 'Michael', 'Michael', 'Pam', 'Jo', 'Andy', 'Andy', 'Jo', 'Jo', 'Michael', 'Michael', 'Gabe', 'Pam', 'Creed', 'Nick', 'Nick', 'Dwight', 'Nick', 'Dwight', 'Nick', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'The', 'The', 'The', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Pam', 'Pam', 'Phyllis', 'Pam', 'Phyllis', 'Phyllis', 'Creed', 'Michael', 'Erin', 'Michael', 'Oscar', 'Michael', 'Pam', 'Pam', 'Dwight', 'Michael', 'Oscar', 'Stanley', 'Creed', 'Gabe', 'Michael', 'Pam', 'Pam', 'Dwight', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Dwight', 'Pam', 'Dwight', 'Pam', 'Dwight', 'Pam', 'Andy', 'Pam', 'Andy', 'Phyllis', 'Dwight', 'Dwight', 'Mose', 'Mose', 'Dwight', 'Mose', 'Dwight', 'Dwight', 'Pam', 'Pam', 'Pam', 'Dwight', 'Dwight', 'Pam', 'Dwight', 'Dwight', 'Dwight', 'The', 'Dwight', 'The', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Toby', 'Dwight', 'Toby', 'Michael', 'Dwight', 'Dwight', 'Andy', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'The', 'Pam', 'The', 'Andy', 'Dwight', 'Pam', 'Dwight', 'Dwight', 'Mose', 'Pam', 'Kelly', 'Kelly', 'Kelly', 'Dwight', 'Andy', 'Dwight', 'Andy', 'Toby', 'Michael', 'Dwight', 'The', 'Andy', 'Dwight', 'Dwight', 'Dwight', 'Kelly', 'Dwight', 'Oscar', 'Dwight', 'Oscar', 'Dwight', 'Dwight', 'Phyllis', 'Dwight', 'Dwight', 'Erin', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Andy', 'Dwight', 'Andy', 'Dwight', 'Andy', 'Dwight', 'Michael', 'Andy', 'Erin', 'Andy', 'Andy', 'Pam', 'Andy', 'Pam', 'Andy', 'Pam', 'Andy', 'Michael', 'Stanley', 'Erin', 'Andy', 'Erin', 'Pam', 'Meredith', 'Michael', 'Meredith', 'Mich ...
# Pam: ['Jim', 'Michael', 'Dwight', 'Jim', 'Jim', 'Donna', 'Jim', 'Donna', 'Donna', 'Donna', 'Donna', 'Michael', 'Donna', 'Jim', 'Donna', 'Jim', 'Michael', 'Jim', 'Michael', 'Donna', 'Michael', 'Jim', 'Jim', 'Jim', 'Jim', 'Michael', 'Jim', 'Michael', 'Jim', 'Jim', 'Jim', 'Dwight', 'Kelly', 'Kevin', 'Andy', 'Donna', 'Jim', 'Jim', 'Kelly', 'Jim', 'Kelly', 'Ryan', 'Kelly', 'Ryan', 'Dwight', 'Jim', 'Jim', 'Michael', 'Jim', 'Jim', 'Michael', 'Jim', 'Michael', 'Jim', 'Michael', 'Jim', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Phyllis', 'Michael', 'Phyllis', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Donna', 'Dwight', 'Dwight', 'Jim', 'Stanley', 'Michael', 'Stanley', 'Michael', 'Dwight', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Dwight', 'Michael', 'Dwight', 'Andy', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Jim', 'Jim', 'Jim', 'Michael', 'Dwight', 'Michael', 'Jim', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Holly', 'Michael', 'Holly', 'Carol', 'Helene', 'Michael', 'Helene', 'Michael', 'Helene', 'Jim', 'Helene', 'Jim', 'Michael', 'Michael', 'Jim', 'Creed', 'Michael', 'Jim', 'Creed', 'Creed', 'Creed', 'Andy', 'Donna', 'Donna', 'Donna', 'Michael', 'Michael', 'Michael', 'Michael', 'Jim', 'Michael', 'Jim', 'Michael', 'Jim', 'Michael', 'Michael', 'Jim', 'Michael', 'Jim', 'Michael', 'Jim', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Donna', 'Michael', 'Donna', 'Donna', 'Michael', 'Darryl', 'Andy', 'Michael', 'Toby', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Gabe', 'Michael', 'Gabe', 'Andy', 'Jim', 'Andy', 'Michael', 'Erin', 'The', 'Erin', 'Erin', 'Erin', 'Michael', 'Erin', 'Michael', 'Michael', 'Michael', 'Erin', 'Erin', 'Erin', 'Erin', 'Erin', 'Erin', 'Toby', 'Dwight', 'Toby', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Michael', 'Dwight', 'Michael', 'Erin', 'Michael', 'Erin', 'Michael', 'Michael', 'Kevin', 'The', 'Phyllis', 'Jim', 'Michael', 'Jim', 'Michael', 'Michael', 'Michael', 'Michael', 'Jim', 'Jim', 'Michael', 'Jim', 'Jim', 'Billy', 'Michael', 'Michael', 'Michael', 'Donna', 'Michael', 'Donna', 'Michael', 'Gabe', 'Gabe', 'Jim', 'Jim', 'Gabe', 'Jim', 'Gabe', 'Jim', 'Gabe', 'Gabe', 'Jim', 'Gabe', 'Michael', 'Andy', 'Michael', 'Michael', 'Kevin', 'Phyllis', 'Kevin', 'Phyllis', 'Michael', 'Jim', 'Jim', 'Darryl', 'Jim', 'Darryl', 'Jim', 'Darryl', 'Jim', 'Darryl', 'Darryl', 'Jim', 'Darryl', 'Phyllis', 'Michael', 'Michael', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Andy', 'Jim', 'Andy', 'Jim', 'Andy', 'Jim', 'Jo', 'Jo', 'Michael', 'Jim', 'Jo', 'Michael', 'Michael', 'Michael', 'Michael', 'Darryl', 'Michael', 'Michael', 'Meredith', 'Meredith', 'Darryl', 'Michael', 'Meredith', 'Darryl', 'Michael', 'Kelly', 'Michael', 'Kelly', 'Michael', 'Kelly', 'Michael', 'Michael', 'Kelly', 'Michael', 'Michael', 'Darryl', 'Michael', 'Michael', 'Jo', 'Michael', 'Creed', 'Gabe', 'Angela', 'Dwight', 'Dwight', 'Kevin', 'Jim', 'Jim', 'Phyllis', 'Jim', 'Phyllis', 'Phyllis', 'Phyllis', 'Phyllis', 'Justin', 'Michael', 'Phyllis', 'Michael', 'Oscar', 'The', 'Andy', 'Jim', 'Jim', 'Dwight', 'Jim', 'Dwight', 'Angela', 'Jim', 'Dwight', 'Angela', 'Kevin', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Hank', 'Dwight', 'Hank', 'Hank', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Michael', 'Michael', 'Oscar', 'Oscar', 'Jim', 'Dwight', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Dwight', 'Jim', 'Dwight', 'Jim', 'Andy', 'Phyllis', 'Andy', 'The', 'Dwight', 'J ...
# Stanley: ['Dwight', 'Dwight', 'Erin', 'Erin', 'Dwight', 'Oscar', 'Michael', 'Michael', 'Pam', 'Michael', 'Pam', 'Michael', 'Andy', 'Gabe', 'Gabe', 'Jim', 'Angela', 'Michael', 'Michael', 'Michael', 'Andy', 'Gabe', 'Andy', 'Andy', 'Phyllis', 'Phyllis', 'Nick', 'Toby', 'Ryan', 'Kelly', 'Angela', 'Andy', 'Michael', 'Andy', 'Toby', 'Toby', 'Erin', 'Michael', 'Andy', 'Kelly', 'Creed', 'Jim', 'Dwight', 'Jim', 'Dwight', 'Erin', 'Pam', 'Pam', 'Jim', 'Kelly', 'Jim', 'Michael', 'Phyllis', 'Michael', 'Andy', 'Oscar', 'Michael', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Oscar', 'Andy', 'Oscar', 'Andy', 'Andy', 'Holly', 'Holly', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Phyllis', 'Michael', 'Phyllis', 'Phyllis', 'Phyllis', 'Michael', 'Jim', 'Dwight', 'Michael', 'Darryl', 'Kevin', 'Phyllis', 'Phyllis', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Jim', 'Pam', 'Dwight', 'Oscar', 'Oscar', 'Kevin', 'Kevin', 'Oscar', 'Phyllis', 'Oscar', 'Oscar', 'Pam', 'Angela', 'Kevin', 'Michael', 'Kevin', 'Michael', 'Jessica', 'Michael', 'Oscar', 'Michael', 'Darryl', 'Michael', 'Erin', 'Erin', 'Michael', 'Kevin', 'Michael', 'Kevin', 'Michael', 'Phyllis', 'Ryan', 'Michael', 'Pam', 'Michael', 'Pam', 'Ryan', 'Ryan', 'Michael', 'Ryan', 'Michael', 'Ryan', 'Andy', 'Michael', 'Michael', 'Andy', 'Dwight', 'Dwight', 'Pam', 'Dwight', 'Jim', 'Dwight', 'Pam', 'Dwight', 'Dwight', 'Michael', 'Kevin', 'Michael', 'Gabe', 'Angela', 'Michael', 'Kelly', 'Pam', 'Kelly', 'Pam', 'Michael', 'Andy', 'Dwight', 'Jim', 'Dwight', 'Toby', 'Jada', 'Darryl', 'Jada', 'Darryl', 'Pam', 'Jada', 'Darryl', 'Pam', 'Dwight', 'Andy', 'Dwight', 'Andy', 'Phyllis', 'Andy', 'Phyllis', 'Phyllis', 'Andy', 'Phyllis', 'Andy', 'Phyllis', 'Andy', 'Phyllis', 'Gabe', 'The', 'Michael', 'Darryl', 'Andy', 'Phyllis', 'Andy', 'Holly', 'Holly', 'Michael', 'Deangelo', 'Michael', 'Darryl', 'Deangelo', 'Michael', 'Ryan', 'Michael', 'Kevin', 'Kevin', 'Michael', 'Michael', 'Michael', 'Dwight', 'Michael', 'Michael', 'Meredith', 'Ryan', 'Creed', 'Michael', 'Andy', 'Andy', 'Andy', 'Michael', 'Phyllis', 'Michael', 'Andy', 'Andy', 'Michael', 'Michael', 'Pam', 'Michael', 'Pam', 'Jim', 'Michael', 'Michael', 'Kevin', 'Michael', 'Kevin', 'Michael', 'Andy', 'Pam', 'Dwight', 'Dwight', 'Andy', 'Erin', 'Phyllis', 'Darryl', 'Darryl', 'The', 'Ryan', 'Jim', 'Jim', 'Jim', 'Meredith', 'Angela', 'Pam', 'Jim', 'Jim', 'Andy', 'Dwight', 'Jim', 'Andy', 'Dwight', 'Jim', 'Erin', 'Jim', 'Andy', 'Phyllis', 'Andy', 'Andy', 'Kevin', 'Dwight', 'Andy', 'Pam', 'Dwight', 'Pam', 'Dwight', 'Robert', 'Andy', 'Phyllis', 'Andy', 'Jim', 'Andy', 'Phyllis', 'Jim', 'Andy', 'Dwight', 'Andy', 'Kelly', 'Andy', 'Jim', 'Andy', 'Jim', 'Meredith', 'Erin', 'Kevin', 'Andy', 'Kevin', 'Oscar', 'Andy', 'Kevin', 'The', 'Andy', 'Oscar', 'Andy', 'Oscar', 'Andy', 'Robert', 'Andy', 'Andy', 'Robert', 'Andy', 'Andy', 'Robert', 'Andy', 'Robert', 'Andy', 'Andy', 'Robert', 'Andy', 'Oscar', 'Dwight', 'Erin', 'Ryan', 'Dwight', 'Jim', 'Andy', 'Dwight', 'Dwight', 'Oscar', 'Erin', 'Kevin', 'Robert', 'The', 'Robert', 'Robert', 'Darryl', 'Dwight', 'Darryl', 'Dwight', 'Dwight', 'Robert', 'Kevin', 'Kevin', 'Andy', 'Andy', 'Jim', 'Andy', 'Jim', 'Meredith', 'Jim', 'Meredith', 'Andy', 'Meredith', 'Andy', 'Dwight', 'Erin', 'Robert', 'Andy', 'Andy', 'Jim', 'Andy', 'Phyllis', 'Cathy', 'Kevin', 'Kevin', 'Erin', 'Kevin', 'Kevin', 'Kelly', 'Kelly', 'Dwight', 'Dwight', 'Jim', 'Dwight', 'Jim', 'Jim', 'Dwight', 'Dwight', 'Jim', 'Phyllis', 'Dwight', 'Dwight', 'Dwight', 'Erin', 'Jessica', 'Erin', 'Jessica', 'Erin', 'Andy', 'Erin', 'Dwight', 'Phyllis', 'Jim', 'Phyllis', 'Jim', 'Dwight', 'Jim', 'Jim', 'Jim', 'Pam', 'Jim', 'Phyllis', 'Darryl', 'Pam', 'Angela', 'Dwight', 'Dwight', 'Andy', 'Meredith', 'Kevin', 'Kevin', 'Angela', 'Andy', 'Dwight', 'Andy', 'Dwight', 'Andy', 'Erin', 'Dwight', 'The', 'Ryan', 'Dwight', 'Dwight', 'Jim', 'Dwight', 'Erin', 'Ryan', 'Jim', 'Jim', 'Kenny', 'Jim', 'Kenny', 'Jim', 'Andy', 'Creed', 'Andy', 'Meredith', 'Andy', 'Jim', 'Jim', 'Jim', 'Dwight', 'Jim', 'Jim', 'Jim', 'Jim', ...
# Kevin: ['Phyllis', 'Creed', 'Phyllis', 'Andy', 'Donna', 'Jim', 'Michael', 'Jim', 'Pam', 'Andy', 'Michael', 'Jim', 'Michael', 'Jim', 'Oscar', 'Michael', 'Andy', 'Andy', 'Michael', 'Michael', 'Dwight', 'Phyllis', 'Michael', 'Michael', 'Pam', 'Michael', 'The', 'The', 'Dwight', 'Angela', 'Phyllis', 'Michael', 'Phyllis', 'Michael', 'Oscar', 'Michael', 'Kelly', 'Ryan', 'Kelly', 'Michael', 'Donna', 'Stanley', 'Jo', 'Jo', 'Jo', 'Jo', 'Jo', 'Jo', 'Jo', 'The', 'Michael', 'Nick', 'Angela', 'Andy', 'Angela', 'Andy', 'Michael', 'Dwight', 'David', 'Andy', 'Andy', 'Angela', 'Erin', 'Erin', 'Ryan', 'Ryan', 'Ryan', 'Ryan', 'Ryan', 'Ryan', 'Ryan', 'Ryan', 'Gabe', 'Ryan', 'Gabe', 'Gabe', 'Gabe', 'Ryan', 'Erin', 'Creed', 'Erin', 'Creed', 'Erin', 'Angela', 'Dwight', 'Jim', 'Dwight', 'Pam', 'Oscar', 'The', 'Pam', 'Pam', 'Dwight', 'Pam', 'Dwight', 'Dwight', 'Stanley', 'Kelly', 'Creed', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Pam', 'Meredith', 'Andy', 'Michael', 'Andy', 'Michael', 'Michael', 'Michael', 'Michael', 'Kelly', 'Andy', 'Phyllis', 'The', 'Phyllis', 'The', 'Andy', 'Andy', 'Andy', 'Creed', 'Andy', 'Creed', 'The', 'Pam', 'Jim', 'Darryl', 'Oscar', 'Meredith', 'Oscar', 'Oscar', 'Meredith', 'Kelly', 'Andy', 'Bob', 'Andy', 'Bob', 'Andy', 'Meredith', 'Andy', 'Andy', 'Michael', 'Darryl', 'Andy', 'Darryl', 'Andy', 'Darryl', 'Andy', 'Andy', 'Darryl', 'Andy', 'Darryl', 'Andy', 'Darryl', 'Darryl', 'Andy', 'Andy', 'Andy', 'Darryl', 'Phyllis', 'Phyllis', 'Stanley', 'The', 'Oscar', 'Michael', 'Oscar', 'Ryan', 'Creed', 'Jim', 'Phyllis', 'Dwight', 'Pam', 'Andy', 'The', 'Stanley', 'Phyllis', 'Angela', 'Andy', 'Andy', 'Jim', 'Erin', 'Kelly', 'Toby', 'Erin', 'Kelly', 'Toby', 'Erin', 'Kelly', 'Toby', 'Erin', 'Kelly', 'Toby', 'Michael', 'Michael', 'Gabe', 'Michael', 'Gabe', 'Michael', 'Gabe', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', '
am', 'The', 'Dwight', 'The', 'Phyllis', 'Pam', 'Pam', 'Oscar', 'Oscar', 'Oscar', 'Dwight', 'Andy', 'Dwight', 'Andy', 'Dwight', 'Andy', 'Dwight', 'Andy', 'Michael', 'Kelly', 'Michael', 'Gabe', 'Erin', 'Holly', 'Michael', 'Holly', 'Oscar', 'Oscar', 'Oscar', 'Darryl', 'Oscar', 'Darryl', 'Phyllis', 'Darryl', 'Phyllis', 'Darryl', 'Oscar', 'Kevin', 'Kevin', 'Kevin', 'Erin', 'Andy', 'Dwight', 'Dwight', 'Ryan', 'Kevin', 'Michael', 'Oscar', 'Michael', 'Oscar', 'Dwight', 'Michael', 'Pam', 'Andy', 'Holly', 'Michael', 'Ryan', 'Mi ...
# Phyllis: ['Creed', 'Pam', 'Kevin', 'Pam', 'Kevin', 'Andy', 'Michael', 'Bob', 'Andy', 'Michael', 'Michael', 'Michael', 'Jim', 'Michael', 'Andy', 'Michael', 'Michael', 'Michael', 'Michael', 'Andy', 'Donna', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Kevin', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Dwight', 'Michael', 'Andy', 'Andy', 'Andy', 'Jo', 'Dwight', 'Dwight', 'Nick', 'Nick', 'Angela', 'Andy', 'Kevin', 'Andy', 'Dwight', 'Dwight', 'Stanley', 'Justin', 'Meredith', 'Michael', 'Justin', 'Meredith', 'Michael', 'Michael', 'Darryl', 'Michael', 'Michael', 'Dwight', 'Gabe', 'Michael', 'Jim', 'Michael', 'Andy', 'Michael', 'Erin', 'The', 'Dwight', 'The', 'Michael', 'Pam', 'Jim', 'Dwight', 'Jim', 'Dwight', 'Michael', 'Michael', 'Andy', 'Michael', 'Andy', 'Michael', 'Andy', 'Stanley', 'Andy', 'Andy', 'Michael', 'Andy', 'Dwight', 'Dwight', 'Ryan', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Pam', 'Stanley', 'Andy', 'Holly', 'The', 'Andy', 'Kevin', 'Dan', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Dwight', 'Andy', 'Dwight', 'Jim', 'Michael', 'Dwight', 'Dwight', 'Stanley', 'Michael', 'Jim', 'Michael', 'Jim', 'Michael', 'Michael', 'Dwight', 'Michael', 'Dwight', 'Pam', 'Creed', 'Creed', 'Pam', 'Jim', 'Oscar', 'Ryan', 'Pam', 'Michael', 'Darryl', 'Jim', 'Erin', 'Todd', 'Jim', 'Stanley', 'Michael', 'Jessica', 'Michael', 'Michael', 'Ryan', 'Michael', 'Michael', 'Michael', 'Michael', 'Dwight', 'Michael', 'Jim', 'Jim', 'Jim', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Kelly', 'Michael', 'Kelly', 'Michael', 'Michael', 'Andy', 'Andy', 'Gabe', 'Andy', 'Erin', 'Gabe', 'Andy', 'Andy', 'Michael', 'Andy', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Erin', 'Erin', 'Erin', 'Erin', 'Bob', 'The', 'Bob', 'The', 'Erin', 'Pam', 'Angela', 'Angela', 'Michael', 'Pam', 'Michael', 'Michael', 'Blue', 'Pam', 'Dwight', 'Michael', 'Erin', 'Bob', 'Pam', 'Stanley', 'Dwight', 'Dwight', 'Pam', 'Dwight', 'Pam', 'Nate', 'Kelly', 'Meredith', 'Dwight', 'Dwight', 'Kelly', 'Gabe', 'Stanley', 'Dwight', 'Jim', 'Toby', 'Toby', 
 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Gabe', 'Jim', 'Gabe', 'Jim', 'Pam', 'Dwight', 'Pam', 'Dwight', 'Pam', 'Pam', 'Michael', 'Holly', 'Gabe', 'Jada', 'Jada', 'Pam', 'Angela', 'Angela', 'Angela', 'Angela', 'Angela', 'Robert', 'Pam', 'Pam', 'Michael', 'Pam', 'Michael', 'Pam', 'Michael', 'Michael', 'Erin', 'Michael', 'Erin', 'Michael', 'Michael', 'Kevin', 'Michael', 'Kevin', 'Michael', 'Michael', 'Pam', 'Pam', 'Darryl', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'The', 'Michael', 'The', 'Michael', 'The', 'Michael', 'Michael', 'Michael', 'Andy', 'Andy', 'The', 'Andy', 'Gabe', 'Erin', 'The', 'Gabe', 'Oscar', 'Holly', 'Michael', 'Holly', 'Oscar', 'Kelly', 'Erin', 'Erin', 'Gabe', 'Erin', 'Michael', 'Michael', 'Michael', 'Pam', 'The', 'Phyllis', 'The', 'Phyllis', 'Erin', 'Jordan', 'Stanley', 'Phyllis', 'Jordan', 'Stanley', 'Phyllis', 'Jordan', 'Stanley', 'Phyllis', 'Stanley', 'Phyllis', 'Jim', 'Pam', 'Kevin', 'Kevin', 'Kevin', 'Kevin', 'The', 'Kevin', 'The', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Kelly', 'Jim', 'Jordan', 'Jordan', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Erin', 'Pam', 'Erin', 'Jo', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Toby', 'The', 'Pam', 'Robert', 'Darryl', 'Robert', 'Darryl', 'Robert', 'Meredith', 'Robert', 'The', 'Kevin', 'Dwight', 'Dwight', 'Pam', 'Dwight', 'Pam', 'Dwight', 'Dwight', 'Oscar', 'Jim', 'Jim', 'Dwight', 'Darryl', 'Andy', 'Jessica', 'Erin', 'Darryl', 'Jessica', 'Andy', 'Stanley', 'Phyllis', 'Cathy', 'Dwight', 'Jim', 'Andy', 'Angela', 'Pam', 'Andy', 'Pam', 'Jim', 'Pam', 'Jim', 'Pam', 'Phyllis', 'Pam', 'Jim', 'Robert', 'Andy', 'Darryl', 'Meredith', 'Andy', 'Dwight', 'Erin', 'Meredith', 'Meredith', 'Toby', 'Andy', 'Pam', 'Dwight', 'Pam', 'Dwight', 'Dwight', 'Erin', 'Andy', 'Erin', 'Nellie', 'Erin', 'Andy', 'Nellie', 'Erin', 'Andy', 'Pam', 'Pam', 'Pam', 'Nellie', 'Dwight', 'Erin', 'Nellie', 'Dwight', 'Erin', 'Andy', 'Pam', 'Andy', 'Kevin', 'Dwight', 'Dwight', 'Toby', 'Toby', 'Jim', 'Jim', 'Andy', 'Andy', 'The', 'Dwight', 'Jim', 'Pam', 'Jim', 'Pam', 'Nellie', 'Andy', 'Roy', 'Nellie', 'Dwight', 'Dwight', 'The', 'Nellie', 'Dwight', 'Meredith', 'Dwight', 'Jim', 'Dwight', 'Andy', 'Pam', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Clark', 'Pam', 'Jim', 'Pam', 'Dwight', 'Dwight', 'Pam', 'Jim', 'Jim', 'Pete', 'Dwight', 'Angela', 'Pam', 'Pam', 'Pam', 'Pete', 'Dwight', 'Oscar', 'Dwight', 'Phyllis', 'Angela', 'Dwight', 'Phyllis', 'Angela', 'Meredith', 'Meredith', 'Erin', 'Erin', 'Pete', 'Pete', 'Oscar', 'Angela', 'Oscar', 'Pam', 'Pam', 'Pete', 'Athlead', 'Jim', 'The', 'Angela', 'Oscar', 'Phyllis', 'Oscar', 'Phyllis', 'Kevin', 'Nellie', 'Angela', 'Erin', 'Pam', 'Jim', 'Pam', 'Oscar', 'Pam', 'Pam', 'Meredith', 'Phyllis', 'Andy', 'Phyllis', 'Andy', 'Meredith', 'Erin', 'The', 'Gabe', 'Toby', 'Toby', 'Toby', 'Dwight', 'Erin', 'Dwight', 'Clark', 'Clark', 'Todd', 'Clark', 'Clark', 'Todd', 'Angela', 'Kevin', 'Angela', 'Angela', 'Dwight', 'Clark', 'Angela', 'Esther', 'Angela', 'Andy', 'Jim', 'Clark', 'Pam', 'Kevin', 'Dwight', 'Oscar', 'Angela', 'Angela', 'Andy', 'Andy', 'Andy', 'Meredith', 'Dwight', 'Erin', 'Kevin', 'Phyllis', 'Stanley', 'Kelly', 'Ravi', 'Ryan', 'Kelly', 'Ravi', 'Ryan', 'Jim', 'Phyllis', 'Jim', 'Jim', 'Phyll ...
# Oscar: ['Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Angela', 'Michael', 'Angela', 'Angela', 'Michael', 'Michael', 'Jim', 'Michael', 'Jim', 'Michael', 'Michael', 'Michael', 'Kevin', 'Dwight', 'Kelly', 'Dwight', 'Pam', 'Michael', 'Michael', 'Ryan', 'Michael', 'Michael', 'Ryan', 'Michael', 'Stanley', 'Michael', 'Jim', 'Michael', 'Michael', 'Kevin', 'Kelly', 'Michael', 'Jim', 'Michael', 'The', 'Dwight', 'Kevin', 'The', 'Kevin', 'Darryl', 'Darryl', 'Michael', 'Jim', 'Michael', 'Michael', 'Darryl', 'Michael', 'Kelly', 'Darryl', 'Michael', 'Michael', 'Erin', 'The', 'Andy', 'Pam', 'Stanley', 'Erin', 'Michael', 'Phyllis', 'Andy', 'Michael', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Jim', 'Pam', 'Jim', 'Dwight', 'Jim', 'Dwight', 'Dwight', 'Dwight', 'Ryan', 'The', 'Michael', 'Andy', 'Andy', 'Meredith', 'Angela', 'Michael', 'Andy', 'Andy', 'Phyllis', 'Andy', 'Andy', 'Meredith', 'Michael', 'Michael', 'Michael', 'Michael', 'Michael', 'Dwight', 'Michael', 'Dwight', 'Michael', 'Dwight', 'Michael', 'Flower', 'Michael', 'Andy', 'Pam', 'Andy', 'Pam', 'Michael', 'Michael', 'Kevin', 'Meredith', 'Kevin', 'Meredith', 'Kevin', 'Meredith', 'Kevin', 'Meredith', 'Meredith', 'Kelly', 'Pam', 'Michael', 'Jim', 'Michael', 'Michael', 'Jim', 'Jim', 'Andy', 'Pam', 'Andy', 'Jim', 'Dwight', 'Jim', 'Jim', 'Dwight', 'Jim', 'Dwight', 'Jim', 'Dwight', 'Jim', '
 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Erin', 'Andy', 'Erin', 'Erin', 'Andy', 'Jim', 'Phyllis', 'Jim', 'Oscar', 'Jim', 'Kelly', 'Kelly', 'Erin', 'Nate', 'Toby', 'Darryl', 'Toby', 'Darryl', 'Toby', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Meredith', 'Andy', 'Andy', 'Meredith', 'Andy', 'Meredith', 'Meredith', 'Andy', 'Meredith', 'Meredith', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Erin', 'Andy', 'Erin', 'Erin', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Erin', 'Andy', 'Erin', 'Dwight', 'Andy', 'Val', 'Kevin', 'Erin', 'Dwight', 'Andy', 'Erin', 'Dwight', 'Erin', 'Erin', 'Andy', 'Erin', 'Erin', 'Dwight', 'Dwight', 'Andy', 'Dwight', 'Jim', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Erin', 'Andy', 'Erin', 'Andy', 'Erin', 'Andy', 'Andy', 'Andy', 'Kenny', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Robert', 'Andy', 'Erin', 'Kenny', 'Kenny', 'Andy', 'Andy']
# Bob: ['Darryl', 'Val', 'Darryl', 'Darryl', 'Darryl', 'Darryl', 'Darryl', 'Darryl', 'Dwight', 'Darryl', 'Dwight', 'Darryl']
# Irene: ['Erin', 'Andy', 'Erin', 'Erin', 'Nellie', 'Robert', 'Erin', 'Erin', 'Erin', 'Erin', 'Erin', 'Andy', 'Erin', 'Andy', 'Andy', 'Erin', 'Andy', 'Andy', 'Erin', 'Erin', 'Erin', 'Erin', 'Erin', 'Andy', 'Andy', 'Andy', 'Erin', 'Andy', 'Erin', 'Erin', 'Erin', 'Erin', 'Andy', 'Erin', 'Nellie', 'Jim', 'Jessica', 'Andy', 'Erin', 'Andy', 'Jessica', 'Erin', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Jim', 'Andy', 'Jim', 'Andy', 'Jim', 'Andy', 'Nellie', 'Erin', 'Andy', 'Erin', 'Erin', 'Erin', 'Nellie', 'Erin', 'Nellie', 'Jim', 'Nellie', 'Jim', 'Jim']
# Kenny: ['Andy', 'Andy', 'Jessica', 'Andy', 'Jessica', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Erin', 'Erin', 'Erin', 'Andy', 'Pam', 'Jim', 'Jim', 'Clark']
# Ravi: ['Jim', 'Pam', 'Jim', 'Robert', 'Andy', 'Robert', 'Ryan', 'Kelly', 'Kelly', 'Ryan', 'Phyllis', 'Angela', 'Ryan', 'Ryan', 'Kelly', 'Ryan', 'Kelly', 'Ryan', 'Kelly', 'Ryan', 'Kelly', 'Ryan', 'Kelly', 'Kevin', 'Kevin', 'Ryan', 'Kevin', 'Ryan', 'Kelly', 'Kelly', 'Ryan', 'Phyllis', 'Angela', 'Ryan', 'Ryan', 'Kelly', 'Ryan', 'Kelly', 'Ryan', 'Kelly', 'Ryan', 'Kelly', 'Ryan', 'Kelly', 'Kevin', 'Kevin', 'Ryan', 'Kevin']
# Calvin: ['Darryl', 'Darryl', 'Darryl', 'Darryl', 'Darryl', 'The', 'Darryl', 'Val', 'Darryl']
# Jake: ['Meredith', 'Dwight', 'Dwight']
# Sasha: ['Dwight', 'Jake', 'Meredith']
# Pete: ['Jim', 'Jim', 'The', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Clark', 'Andy', 'Clark', 'Darryl', 'Jim', 'The', 'Jim', 'The', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', '
 'Erin', 'Erin', 'Erin', 'Erin', 'Erin', 'Erin', 'Erin', 'Erin', 'Andy', 'Clark', 'Andy', 'Andy', 'Andy', 'Erin', 'Andy', 'Andy', 'Clark', 'Clark', 'Andy', 'Pam', 'Jim', 'Andy', 'Erin', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Erin', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'The', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Toby', 'Andy', 'Andy', 'Toby', 'Andy', 'Toby', 'Andy', 'Toby', 'Andy', 'Toby', 'Toby', 'Toby', 'Andy', 'Andy', 'Andy', 'Erin', 'Andy', 'Erin', 'Andy', 'Erin', 'Erin', 'Andy', 'Erin', 'Andy', 'Pam', 'Andy', 'Pam', 'Pam', 'Erin', 'Erin', 'Erin', 'Erin', 'Erin', 'Erin', 'Erin', 'Andy', 'Creed', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy' ...
# Clark: ['Stanley', 'Phyllis', 'Toby', 'Toby', 'Toby', 'Stanley', 'Darryl', 'Andy', 'Dwight', 'Andy', 'Dwight', 'Dwight', 'Andy', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Andy', 'Darryl', 'Dwight', 'Darryl', 'Dwight', 'Andy', 'Darryl', 'Dwight', 'Andy', 'Andy', 'Andy', 'Dwight', 'Dwight', 'Dwight', 'Andy', 'Erin', 'Pete', 'Erin', 'Erin', 'Pete', 'Erin', 'Erin', 'Erin', 'Pete', 'Pete', 'Erin', 'Erin', 'Erin', 'Erin', 'Erin', 'Erin', 'Erin', 'Pete', 'Pete', 'Erin', 'Pete', 'Pete', 'Pete', 'Erin', 'Andy', 'Pete', 'Andy', 'Pete', 'Andy', 'Erin', 'Andy', 'Erin', 'Andy', 'Andy', 'Pete', 'Erin', 'Erin', 'Pete', 'Oscar', 'Pete', 'Pete', 'Dwight', 'Erin', 'Andy', 'Pete', 'Andy', 'Andy', 'Pete', 'Andy', 'Pete', 'Pete', 'Pete', 'Pete', 'Andy', 'Erin', 'Andy', 'Andy', 'Andy', 'Erin', 'Erin', 'Erin', 'Andy', 'Andy', 'Andy', 'Erin', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Pete', 'Darryl', 'Jim', 'Darryl', 'Jim', 'Darryl', 'Darryl', 'Darryl', 'Darryl', 'Darryl', 'Darryl', 'Darryl', 'Darryl', 'Darryl', 'Jim', 'Darryl', 'Jim', 'Jim', 'Creed', 'Darryl', 'Jim', 'Stanley', 'Stanley', 'Jim', 'Stanley', 'Jim', 'Jim', 'Jim', 'Jim', 'Pam', 'Jim', 'Pam', 'Pam', 'Darryl', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Kevin', 'Phyllis', 'Dwight', 'Andy', 'Meredith', 'Andy', 'Creed', 'Pam', 'Jim', 'Pam', 'Jim', 'Pam', 'Andy', 'Stanley', 'Dwight', 'Stanley', 'Dwight', 'Darryl', 'Darryl', 'Toby', 'Toby', 'Toby', 'Toby', 'Angela', 'Dwight', 'Jan', 'Hunter', 'Dwight', 'Jan', 'Dwight', 'Phyllis', 'Meredith', 'Oscar', 'Jan', 'Meredith', 'Meredith', 'Jan', 'Meredith', 'Meredith', 'Meredith', 'Meredith', 'Jan', 'Jan', 'Phyllis', 'Oscar', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Erin', 'Dwight', 'Erin', 'Pete', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Oscar', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Pam', 'Dwight', 'Pam', 'Jim', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Athlead', 'Dwight', 'Athlead', 'Darryl', 'Athlead', 'Darryl', 'Athlead', 'Athlead', 'Darryl', 'Athlead', 'Athlead', 'Darryl', 'Athlead', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Oscar', 'Dwight', 'Oscar', 'Nellie', 'Dwight', 'The', 'Dwight', 'Dwight', 'Dwight', 'Pam', 'Dwight', 'Pam', 'Erin', 'Dwight', 'Dwight', 'Kevin', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Jim', 'Dwight', 'Jan', 'Dwight', 'Jan', 'Dwight', 'Dwight', 'Dwight', 'Pam', 'Jim', 'Rolf', 'Rolf', 'Rolf', 'Rolf', 'Rolf', 'Rolf', 'Rolf', 'Rolf', 'Dwight', 'Dwight', 'Rolf', 'Rolf', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Dwight', 'Jim', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Rolf', 'Dwight', 'Rolf', 'Dwight', 'Rolf', 'Dwight', 'Stanley', 'Nate', 'Dwight', 'Zeke', 'Zeke', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Charles', 'Angela', 'Pam', 'Jim', 'Pam', 'Pam', 'Pam', 'Dwight', 'Dwight', 'Pam', 'Dwight', 'Dwight', 'Pam', 'Dwight', 'Dwight', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Dwight', 'Pam', 'Dwight', 'Pam', 'Darryl', 'Oscar', 'Darryl', 'Darryl', 'Nellie', 'Nellie', 'Nellie', 'Nellie', 'Nellie', 'Nellie', 'Nellie', 'Oscar', 'Oscar', 'Dwight', 'Andy', 'Andy', 'Jan', 'Kevin', 'Dwight', ...
# Roy: ['Darryl', 'Darryl', 'Jim', 'Jim', 'Jim', 'Pam', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Jim', 'Kenny', 'Jim', 'Kenny', 'Jim', 'Jim', 'Pam', 'Darryl', 'Darryl', 'Billy', 'Pam']
# Brian: ['Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Darryl', 'Pam', 'Darryl', 'Darryl', 'Pam', 'Erin', 'Erin', 'Erin', 'Erin', 'Pam', 'Jim', 'Pam', 'Erin', 'Pam', 'Meredith', 'Meredith', 'Meredith', 'Meredith', 'Meredith', 'Meredith', 'Meredith', 'Meredith', 'Meredith', 'Clark', 'Dwight', 'Pam', 'Oscar', 'Angela', 'Oscar', 'Angela', 'Oscar', 'Oscar', 'Angela', 'Oscar', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Jim', 'Pam', 'Jim', 'Darryl', 'Jim', 'Darryl', 'Jim', 'Pam', 'Pam', 'Jim', 'Pam', 'Jim', 'Pam', 'Pam', 'Jim', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Dwight', 'Pam', 'Dwight', 'Andy', 'Dwight', 'Andy', 'Dwight', 'Jim', 'Pam', 'Pam', 'Pam', 'Pam', 'Jim', 'Jim', 'Andy', 'Dwight', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Angela', 'Pam', 'Angela', 'Oscar', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Jim', 'Pam', 'Jim', 'Pam', 'Pam', 'Pam', 'Jim', 'Pam', 'Jim', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Jim']
# Rolf: ['Clark', 'Clark', 'Clark', 'Clark', 'Clark', 'Dwight', 'Clark', 'Dwight', 'Dwight', 'Dwight', 'Pam', 'David', 'Dwight', 'Jim', 'Pam', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'David', 'Dwight', 'David', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Jim', 'Jim', 'Jim', 'Clark']
# Troy: ['Zeke', 'Darryl', 'Jim']
# Zeke: ['Dwight', 'Mose', 'Clark', 'Clark', 'Dwight', 'Dwight', 'Darryl', 'Jim', 'Dwight', 'Dwight', 'Jim', 'Jim', 'Dwight', 'Mose', 'Mose', 'Dwight', 'Dwight', 'Oscar', 'Oscar', 'Dwight', 'Dwight', 'Dwight', 'Oscar', 'Dwight', 'Oscar', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Mose', 'Dwight', 'Mose', 'Dwight', 'Jim', 'Dwight', 'Jim', 'Jim', 'Dwight', 'Dwight', 'Jim', 'Dwight', 'Jim', 'Jim', 'Dwight', 'Dwight']
# Isaac: ['Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Pam', 'Jim']
# Esther: ['Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Zeke', 'Dwight', 'Angela', 'Pam', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Clark', 'Dwight', 'Clark', 'Dwight', 'Robert', 'Angela', 'Oscar', 'Dwight', 'Dwight', 'Nellie', 'Dwight', 'Nellie', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Andy', 'Andy', 'Andy', 'Andy', 'Andy', 'Dwight', 'Angela', 'Dwight', 'Jim', 'David', 'Jim', 'Dwight', 'Dwight', 'Andy', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Dwight', 'Jim', 'Jim']
# Carol: ['Jim', 'Pam', 'Jim', 'Jim', 'Pam', 'Jim']

# %%
connections_dict['Dwight']
# Out:
# ['Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Oscar',
#  'Michael',
#  'Michael',
#  'Jim',
#  'Jim',
#  'Pam',
#  'Jim',
#  'Gabe',
#  'Darryl',
#  'Gabe',
#  'Darryl',
#  'Gabe',
#  'The',
#  'Gabe',
#  'The',
#  'Gabe',
#  'The',
#  'Gabe',
#  'Gabe',
#  'Gabe',
#  'Gabe',
#  'Darryl',
#  'Gabe',
#  'Darryl',
#  'Michael',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Michael',
#  'Kelly',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Donna',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Michael',
#  'Kelly',
#  'Michael',
#  'Donna',
#  'Kelly',
#  'Ryan',
#  'Kelly',
#  'Kelly',
#  'Ryan',
#  'Ryan',
#  'Ryan',
#  'Ryan',
#  'Kelly',
#  'Kelly',
#  'Ryan',
#  'Ryan',
#  'Kelly',
#  'Darryl',
#  'Mose',
#  'Kelly',
#  'Gabe',
#  'Gabe',
#  'Gabe',
#  'Darryl',
#  'Gabe',
#  'Darryl',
#  'Gabe',
#  'Darryl',
#  'Kelly',
#  'Gabe',
#  'Kelly',
#  'Kelly',
#  'Gabe',
#  'Kelly',
#  'Erin',
#  'Erin',
#  'Stanley',
#  'Erin',
#  'Stanley',
#  'Stanley',
#  'Stanley',
#  'Stanley',
#  'Erin',
#  'Stanley',
#  'Erin',
#  'Oscar',
#  'Oscar',
#  'Oscar',
#  'Kelly',
#  'Kelly',
#  'Erin',
#  'Erin',
#  'Kelly',
#  'Kelly',
#  'Gabe',
#  'Kelly',
#  'Gabe',
#  'Pam',
#  'Gabe',
#  'Pam',
#  'Michael',
#  'Gabe',
#  'Pam',
#  'Michael',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Michael',
#  'Kelly',
#  'Michael',
#  'Donna',
#  'Michael',
#  'Donna',
#  'Michael',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Pam',
#  'Pam',
#  'Jim',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Pam',
#  'Pam',
#  'Jim',
#  'Michael',
#  'Michael',
#  'Darryl',
#  'Meredith',
#  'Pam',
#  'Michael',
#  'Pam',
#  'Andy',
#  'Michael',
#  'Andy',
#  'Michael',
#  'Donna',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Andy',
#  'Michael',
#  'Andy',
#  'Stanley',
#  'Andy',
#  'Stanley',
#  'Stanley',
#  'Donna',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'The',
#  'The',
#  'Donna',
#  'Michael',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Donna',
#  'Michael',
#  'Michael',
#  'Donna',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'The',
#  'The',
#  'The',
#  'Michael',
#  'Toby',
#  'Michael',
#  'Michael',
#  'Creed',
#  'Oscar',
#  'Phyllis',
#  'Phyllis',
#  'Toby',
#  'Toby',
#  'Andy',
#  'Toby',
#  'Phyllis',
#  'Toby',
#  'Andy',
#  'Pam',
#  'Pam',
#  'Michael',
#  'Pam',
#  'Michael',
#  'Erin',
#  'Michael',
#  'Michael',
#  'Kevin',
#  'Angela',
#  'Angela',
#  'The',
#  'Angela',
#  'The',
#  'Angela',
#  'The',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Andy',
#  'Angela',
#  'Andy',
#  'Pam',
#  'Andy',
#  'Pam',
#  'Phyllis',
#  'Angela',
#  'Andy',
#  'Michael',
#  'Angela',
#  'Andy',
#  'Michael',
#  'Angela',
#  'Andy',
#  'Michael',
#  'Angela',
#  'Andy',
#  'Michael',
#  'Angela',
#  'Andy',
#  'Michael',
#  'Andy',
#  'Michael',
#  'Andy',
#  'Andy',
#  'Michael',
#  'Andy',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Andy',
#  'Angela',
#  'Andy',
#  'Michael',
#  'Creed',
#  'Michael',
#  'Michael',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Jim',
#  'Angela',
#  'Jim',
#  'Pam',
#  'Jim',
#  'Pam',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Jo',
#  'Nick',
#  'Nick',
#  'Nick',
#  'Nick',
#  'Nick',
#  'Oscar',
#  'Oscar',
#  'The',
#  'Kevin',
#  'Kevin',
#  'Nick',
#  'Kevin',
#  'Jo',
#  'Jo',
#  'Jo',
#  'Jo',
#  'Jo',
#  'Jo',
#  'Jo',
#  'Jo',
#  'Michael',
#  'Jo',
#  'Michael',
#  'Andy',
#  'Toby',
#  'Toby',
#  'The',
#  'The',
#  'Michael',
#  'Jo',
#  'Michael',
#  'Jo',
#  'Jo',
#  'Michael',
#  'Jo',
#  'Creed',
#  'Michael',
#  'Jo',
#  'Creed',
#  'Jim',
#  'Andy',
#  'Andy',
#  'David',
#  'Andy',
#  'Gabe',
#  'Nick',
#  'Ryan',
#  'Kelly',
#  'Hank',
#  'Andy',
#  'Phyllis',
#  'Andy',
#  'Phyllis',
#  'Phyllis',
#  'Phyllis',
#  'Phyllis',
#  'Stanley',
#  'Kevin',
#  'Kevin',
#  'Jim',
#  'Kevin',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Kelly',
#  'Oscar',
#  'The',
#  'Jim',
#  'The',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Pam',
#  'Jim',
#  'Gabe',
#  'Gabe',
#  'Jo',
#  'Michael',
#  'Toby',
#  'Michael',
#  'Toby',
#  'Michael',
#  'Michael',
#  'Pam',
#  'Pam',
#  'Hank',
#  'Pam',
#  'Hank',
#  'Hank',
#  'Hank',
#  'Hank',
#  'Pam',
#  'Pam',
#  'Pam',
#  'Pam',
#  'Pam',
#  'Pam',
#  'Pam',
#  'Pam',
#  'Pam',
#  'Michael',
#  'Pam',
#  'Michael',
#  'Oscar',
#  'Jim',
#  'Pam',
#  'Andy',
#  'Pam',
#  'The',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Mose',
#  'Jim',
#  'Mose',
#  'Mose',
#  'Jim',
#  'Mose',
#  'Mose',
#  'Mose',
#  'Mose',
#  'Pam',
#  'Pam',
#  'Jim',
#  'Pam',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Pam',
#  'Jim',
#  'Jim',
#  'Jim',
#  'The',
#  'Jim',
#  'The',
#  'Jim',
#  'The',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Toby',
#  'Jim',
#  'Toby',
#  'Michael',
#  'Phyllis',
#  'The',
#  'The',
#  'The',
#  'Ryan',
#  'Jim',
#  'Jim',
#  'Andy',
#  'Toby',
#  'Toby',
#  'Phyllis',
#  'Michael',
#  'Andy',
#  'Stanley',
#  'Jim',
#  'Stanley',
#  'Jim',
#  'Pam',
#  'Jim',
#  'Pam',
#  'Jim',
#  'Mose',
#  'Pam',
#  'Kelly',
#  'Kelly',
#  'Creed',
#  'Erin',
#  'Andy',
#  'Toby',
#  'Michael',
#  'Andy',
#  'Andy',
#  'Jim',
#  'Andy',
#  'Jim',
#  'The',
#  'The',
#  'Andy',
#  'Kelly',
#  'Oscar',
#  'Ryan',
#  'The',
#  'Ryan',
#  'The',
#  'Pam',
#  'Darryl',
#  'Darryl',
#  'Andy',
#  'Darryl',
#  'Andy',
#  'Angela',
#  'Angela',
#  'Andy',
#  'Michael',
#  'Andy',
#  'Michael',
#  'Toby',
#  'Erin',
#  'Erin',
#  'Toby',
#  'Angela',
#  'Angela',
#  'Toby',
#  'Angela',
#  'Toby',
#  'Michael',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Andy',
#  'Jim',
#  'Andy',
#  'Michael',
#  'Michael',
#  'Toby',
#  'Michael',
#  'Andy',
#  'Michael',
#  'Andy',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Andy',
#  'Angela',
#  'Angela',
#  'Andy',
#  'Angela',
#  'Andy',
#  'Kelly',
#  'Andy',
#  'Kelly',
#  'Ryan',
#  'Angela',
#  'Pam',
#  'Erin',
#  'Pam',
#  'Erin',
#  'Pam',
#  'Angela',
#  'Michael',
#  'Todd',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Angela',
#  'Andy',
#  'Erin',
#  'Gabe',
#  'Mose',
#  'Nate',
#  'Nate',
#  'Mose',
#  'Nate',
#  'Nate',
#  'Nate',
#  'Nate',
#  'Nate',
#  'Nate',
#  'Nate',
#  'Nate',
#  'Nate',
#  'Nate',
#  'Angela',
#  'Nate',
#  'Angela',
#  'Nate',
#  'Angela',
#  'Nate',
#  'Phyllis',
#  'Nate',
#  'Phyllis',
#  'Ryan',
#  'Ryan',
#  'Kelly',
#  'Andy',
#  'Ryan',
#  'Kelly',
#  'Andy',
#  'Kelly',
#  'Andy',
#  'Nate',
#  'Nate',
#  'Kelly',
#  'Pam',
#  'Pam',
#  'Nate',
#  'Andy',
#  'Andy',
#  'Erin',
#  'Erin',
#  'Andy',
#  'Erin',
#  'Erin',
#  'Michael',
#  'The',
#  'Jan',
#  'The',
#  'Jan',
#  'The',
#  'Michael',
#  'Holly',
#  'Michael',
#  'Holly',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Donna',
#  'Michael',
#  'Donna',
#  'Michael',
#  'Donna',
#  'Michael',
#  'Donna',
#  'Donna',
#  'Michael',
#  'Andy',
#  'Michael',
#  'Jan',
#  'Michael',
#  'Jan',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Jan',
#  'Michael',
#  'Jan',
#  'Michael',
#  'Helene',
#  'Michael',
#  'Jan',
#  'Jan',
#  'Michael',
#  'Holly',
#  'Holly',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Michael',
#  'Andy',
#  'Darryl',
#  'Andy',
#  'Andy',
#  'Darryl',
#  'Andy',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Darryl',
#  'Andy',
#  'Darryl',
#  'Michael',
#  'Oscar',
#  'Michael',
#  'Michael',
#  'Flower',
#  'Michael',
#  'Michael',
#  'The',
#  'Michael',
#  'The',
#  'Michael',
#  'Oscar',
#  'The',
#  'Michael',
#  'Oscar',
#  'Oscar',
#  'Michael',
#  'Oscar',
#  'Pam',
#  'Michael',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Andy',
#  'Jim',
#  'Andy',
#  'Dan',
#  'Jim',
#  'Jim',
#  'The',
#  'Jim',
#  'The',
#  'Jim',
#  'Jim',
#  'The',
#  'Jim',
#  'The',
#  'Jim',
#  'Pam',
#  'Pam',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Michael',
#  'Jim',
#  'Jim',
#  'Michael',
#  'Jim',
#  'Michael',
#  'Jim',
#  'Jim',
#  'The',
#  'Michael',
#  'Michael',
#  'Jim',
#  'Michael',
#  'Michael',
#  'Jim',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Jim',
#  'Jim',
#  'Phyllis',
#  'Jim',
#  'Jim',
#  'Phyllis',
#  'Jim',
#  'Phyllis',
#  'Stanley',
#  'The',
#  'The',
#  'Erin',
#  'Jim',
#  'Michael',
#  'Jim',
#  'Michael',
#  'Jim',
#  'Michael',
#  'Michael',
#  'Meredith',
#  'Michael',
#  'Meredith',
#  'Michael',
#  'Meredith',
#  'Meredith',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Meredith',
#  'Oscar',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Jim',
#  'Oscar',
#  'Jim',
#  'Oscar',
#  'Jim',
#  'Meredith',
#  'Ryan',
#  'Jim',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Jim',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Jim',
#  'Michael',
#  'Stanley',
#  'Michael',
#  'Michael',
#  'Darryl',
#  'Kevin',
#  'Jim',
#  'Jim',
#  'Pam',
#  'Jim',
#  'Pam',
#  'Pam',
#  'Jim',
#  'Jim',
#  'Michael',
#  'Jim',
#  'Jim',
#  'Michael',
#  'Jim',
#  'Michael',
#  'The',
#  'Michael',
#  'The',
#  'Kevin',
#  'Stanley',
#  'Stanley',
#  'Oscar',
#  'Jim',
#  'Jim',
#  'Pam',
#  'Pam',
#  'Pam',
#  'Pam',
#  'Pam',
#  'Jim',
#  'Jim',
#  'Gabe',
#  'Michael',
#  'Gabe',
#  'Pam',
#  'Phyllis',
#  'Creed',
#  'Gabe',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Michael',
#  'Darryl',
#  'Darryl',
#  'Andy',
#  'Andy',
#  'Michael',
#  'Michael',
#  'Gabe',
#  'Kevin',
#  'Gabe',
#  'Michael',
#  'The',
#  'Michael',
#  'Darryl',
#  'The',
#  'Michael',
#  'Darryl',
#  'Pam',
#  ...]

# %%
from collections import Counter

def count_connections(connections_dict):
    # New dictionary to store counts
    connections_count_dict = {}

    for name, connections in connections_dict.items():
        # Count the occurrences of each connection
        connection_counts = Counter(connections)
        # Sort the connections by count in descending order
        sorted_counts = sorted(connection_counts.items(), key=lambda x: x[1], reverse=True)
        # Format the count as 'name count'
        formatted_counts = [f"{conn} {count}" for conn, count in sorted_counts]
        # Assign to the new dictionary
        connections_count_dict[name] = formatted_counts

    return connections_count_dict

# Assuming connections_dict is already populated
# connections_dict = find_connections(folder_path, character_names_list) 

# Count the connections
connections_count_dict = count_connections(connections_dict)

# Print the resulting dictionary in descending order of counts
for name, conns in connections_count_dict.items():
    print(f"{name}: {conns}")
# Out:
# Dwight: ['Jim 1913', 'Andy 708', 'Pam 697', 'Angela 581', 'Michael 441', 'Erin 420', 'Nellie 318', 'Clark 317', 'The 307', 'Darryl 293', 'Oscar 291', 'Kevin 281', 'Stanley 191', 'Phyllis 168', 'Gabe 137', 'Robert 134', 'Ryan 132', 'Kelly 126', 'Toby 109', 'David 105', 'Mose 95', 'Meredith 85', 'Jo 77', 'Nate 70', 'Esther 69', 'Cathy 58', 'Creed 53', 'Deangelo 47', 'Donna 46', 'Holly 45', 'Jan 43', 'Todd 39', 'Pete 31', 'Zeke 30', 'Val 26', 'Rolf 26', 'Troy 25', 'Billy 16', 'Jordan 11', 'Hank 8', 'Nick 7', 'Jessica 7', 'Athlead 5', 'Brian 4', 'Justin 3', 'Asian 2', 'Stephanie 2', 'Jada 2', 'Helene 1', 'Flower 1', 'Dan 1', 'Madge 1', 'Carol 1', 'Sasha 1', 'Jake 1', 'Ravi 1', 'Tom 1', 'Hunter 1', 'Charles 1', 'Josh 1']
# Jim: ['Dwight 1800', 'Pam 1606', 'Andy 566', 'Michael 386', 'Darryl 360', 'Robert 192', 'Kevin 190', 'The 187', 'Erin 174', 'Oscar 162', 'Stanley 153', 'Phyllis 152', 'Nellie 148', 'Angela 136', 'Ryan 130', 'Toby 88', 'Gabe 86', 'Kelly 79', 'Meredith 78', 'Clark 70', 'Cathy 69', 'Deangelo 58', 'Pete 44', 'Jo 43', 'Creed 35', 'Holly 31', 'David 31', 'Tom 30', 'Mose 28', 'Roy 25', 'Todd 22', 'Brian 21', 'Donna 19', 'Athlead 14', 'Jordan 10', 'Hank 9', 'Val 9', 'Jessica 7', 'Kenny 7', 'Nate 6', 'Zeke 6', 'Irene 5', 'Esther 5', 'Nick 4', 'Blue 4', 'Ravi 4', 'Rolf 4', 'Carol 4', 'Billy 3', 'Dan 3', 'Madge 3', 'Justin 3', 'Charles 3', 'Bob 2', 'Cecelia 2', 'State 2', 'Isaac 2', 'Jan 1', 'A. 1', 'Karen 1', 'Gerald 1', 'Elizabeth 1', 'Gil 1', 'Asian 1']
# Pam: ['Jim 1628', 'Dwight 696', 'Michael 486', 'Andy 391', 'Erin 236', 'Angela 236', 'Darryl 182', 'Oscar 174', 'Nellie 166', 'Kevin 163', 'Ryan 156', 'Phyllis 143', 'Meredith 132', 'The 121', 'Brian 121', 'Kelly 93', 'Gabe 73', 'Toby 65', 'Robert 64', 'Stanley 62', 'Creed 62', 'Jan 43', 'Holly 36', 'Deangelo 33', 'Clark 33', 'Pete 31', 'Cathy 27', 'Nate 26', 'David 22', 'Donna 18', 'Bob 14', 'Athlead 14', 'Todd 13', 'Jo 10', 'Helene 9', 'Hank 9', 'Roy 7', 'Jada 6', 'Val 6', 'Isaac 6', 'Carol 5', 'Tom 5', 'Jordan 5', 'A. 4', 'Cecelia 4', 'Mose 3', 'Gil 3', 'Irene 3', 'Ravi 3', 'Blue 2', 'Troy 2', 'Zeke 2', 'State 2', 'Billy 1', 'Justin 1', 'Tony 1', 'Hunter 1', 'Rolf 1', 'Cynthia 1']
# Stanley: ['Andy 114', 'Jim 113', 'Dwight 110', 'Michael 58', 'Phyllis 55', 'Erin 46', 'Oscar 42', 'Kevin 42', 'Pam 41', 'Meredith 22', 'Darryl 21', 'Nellie 20', 'Angela 18', 'The 18', 'Ryan 17', 'Clark 14', 'Robert 13', 'Kelly 10', 'Creed 9', 'Toby 8', 'Pete 8', 'Gabe 5', 'Holly 4', 'Jessica 3', 'Jada 3', 'Cathy 3', 'David 3', 'Deangelo 2', 'Kenny 2', 'Nick 1', 'Nate 1', 'Cynthia 1']
# Kevin: ['Dwight 254', 'Andy 246', 'Oscar 220', 'Angela 210', 'Michael 175', 'Jim 159', 'Pam 151', 'Darryl 132', 'Erin 115', 'Robert 65', 'The 62', 'Nellie 59', 'Ryan 57', 'Phyllis 54', 'Creed 50', 'Toby 46', 'Pete 41', 'Meredith 40', 'Kelly 39', 'Gabe 34', 'Stanley 24', 'Deangelo 22', 'Val 22', 'Holly 19', 'Todd 17', 'Jo 15', 'Clark 9', 'Ravi 6', 'Mose 6', 'David 4', 'A. 4', 'Jessica 3', 'Athlead 3', 'Donna 2', 'Bob 2', 'Helene 2', 'Nick 1', 'Jada 1', 'Madge 1', 'Gerald 1', 'Charles 1', 'Cathy 1', 'Nate 1', 'Jan 1']
# Angela: ['Dwight 570', 'Oscar 368', 'Pam 224', 'Kevin 187', 'Andy 140', 'Jim 101', 'Michael 77', 'Meredith 64', 'Erin 63', 'Phyllis 54', 'The 48', 'Robert 42', 'Toby 34', 'Nellie 34', 'Darryl 26', 'Stanley 25', 'Ryan 21', 'Kelly 19', 'Mose 19', 'Clark 19', 'Gabe 17', 'Pete 16', 'Creed 15', 'Esther 13', 'Deangelo 11', 'Holly 6', 'Todd 4', 'Val 4', 'David 3', 'Nick 2', 'State 2', 'Donna 1', 'Nate 1', 'Helene 1', 'Jo 1', 'Cathy 1', 'Gerald 1', 'Jessica 1', 'Jan 1', 'Athlead 1', 'Brian 1']
# Phyllis: ['Andy 179', 'Dwight 139', 'Michael 114', 'Jim 114', 'Pam 87', 'Erin 73', 'Stanley 65', 'Oscar 58', 'Angela 54', 'Darryl 53', 'Kevin 46', 'Meredith 35', 'Kelly 22', 'The 21', 'Nellie 21', 'Gabe 20', 'Holly 20', 'Creed 18', 'Robert 13', 'Ryan 10', 'Deangelo 10', 'Toby 9', 'Val 9', 'Zeke 8', 'Bob 7', 'Clark 7', 'Jessica 6', 'David 6', 'Todd 4', 'Pete 4', 'Mose 4', 'Jo 3', 'Nick 2', 'Justin 2', 'Blue 2', 'Donna 1', 'Dan 1', 'Nate 1', 'Karen 1', 'Asian 1', 'Cathy 1', 'Elizabeth 1', 'Athlead 1', 'Cynthia 1']
# Creed: ['Pam 70', 'Michael 46', 'Andy 44', 'Jim 41', 'Dwight 34', 'Erin 32', 'Angela 24', 'Phyllis 23', 'Kevin 21', 'Meredith 18', 'Oscar 17', 'The 16', 'Gabe 13', 'Darryl 9', 'Stanley 8', 'Kelly 8', 'Nellie 8', 'Toby 7', 'Clark 7', 'Ryan 6', 'Robert 6', 'Todd 5', 'Jordan 5', 'Pete 5', 'Ravi 4', 'Holly 3', 'Jada 2', 'Jessica 2', 'Donna 1', 'Jo 1', 'Cathy 1', 'Roy 1', 'Athlead 1', 'Esther 1']
# Oscar: ['Angela 358', 'Kevin 237', 'Dwight 237', 'Andy 202', 'Jim 178', 'Pam 178', 'Michael 162', 'Erin 91', 'Darryl 65', 'Phyllis 60', 'Meredith 60', 'Robert 55', 'The 49', 'Toby 48', 'Ryan 47', 'Kelly 36', 'Gabe 28', 'Nellie 28', 'Stanley 24', 'Creed 22', 'Holly 13', 'Pete 13', 'David 10', 'Deangelo 7', 'Clark 6', 'Brian 5', 'Zeke 5', 'Nate 3', 'State 3', 'Gerald 3', 'Jan 3', 'Jada 2', 'Jo 2', 'Esther 2', 'Mose 2', 'Flower 1', 'Todd 1', 'Gil 1', 'Ravi 1', 'Sasha 1', 'Bob 1', 'A. 1']
# Ryan: ['Kelly 215', 'Michael 144', 'Pam 122', 'Dwight 114', 'Jim 97', 'Erin 97', 'Andy 84', 'Oscar 56', 'Kevin 43', 'The 41', 'Robert 30', 'Gabe 29', 'Ravi 24', 'Nellie 22', 'Stanley 19', 'Angela 18', 'Deangelo 17', 'Toby 16', 'Darryl 14', 'Meredith 14', 'Creed 11', 'Phyllis 8', 'Holly 7', 'David 4', 'Cathy 3', 'Donna 2', 'State 2', 'Justin 1', 'Jessica 1', 'Todd 1', 'Jordan 1', 'Jo 1', 'Val 1', 'Elizabeth 1', 'Carol 1', 'Gerald 1']
# Kelly: ['Ryan 178', 'Dwight 126', 'Andy 84', 'Michael 80', 'Pam 66', 'Jim 60', 'Erin 49', 'Kevin 44', 'Gabe 41', 'Oscar 41', 'Angela 28', 'Toby 28', 'Robert 27', 'Meredith 26', 'The 24', 'Deangelo 24', 'Phyllis 23', 'Ravi 23', 'Darryl 22', 'Holly 16', 'Stanley 15', 'Donna 14', 'Jessica 7', 'Creed 6', 'Jordan 4', 'Nellie 3', 'Josh 2', 'Tom 2', 'Jo 2', 'Val 2', 'Nate 1', 'Cathy 1', 'Bob 1']
# Andy: ['Erin 941', 'Dwight 703', 'Darryl 647', 'Jim 599', 'Pam 413', 'Michael 375', 'Robert 328', 'Kevin 318', 'Oscar 276', 'Nellie 242', 'Phyllis 212', 'The 183', 'Gabe 182', 'David 179', 'Stanley 149', 'Angela 141', 'Toby 134', 'Meredith 126', 'Jessica 118', 'Pete 111', 'Kelly 108', 'Ryan 105', 'Clark 98', 'Creed 69', 'Todd 52', 'Deangelo 29', 'Val 23', 'Kenny 21', 'Jan 20', 'Irene 19', 'Jo 17', 'Holly 17', 'Nate 16', 'Tom 13', 'Donna 11', 'Dan 11', 'Bob 11', 'Hank 10', 'Esther 10', 'Jada 7', 'Cathy 5', 'Helene 4', 'Mose 4', 'Brian 4', 'Athlead 4', 'Madge 3', 'Blue 3', 'Jake 3', 'A. 2', 'Sasha 2', 'Ravi 2', 'State 1', 'Jordan 1', 'Asian 1']
# Michael: ['Holly 555', 'Pam 523', 'Dwight 517', 'Jim 455', 'Andy 412', 'Erin 330', 'Kevin 223', 'Oscar 204', 'Darryl 193', 'Donna 184', 'Ryan 181', 'Gabe 172', 'Toby 151', 'Phyllis 136', 'Deangelo 128', 'The 119', 'Kelly 109', 'Stanley 98', 'Angela 97', 'Jo 97', 'Meredith 85', 'Todd 65', 'Creed 53', 'Jan 36', 'David 34', 'Jada 32', 'Billy 30', 'Helene 25', 'Hank 10', 'Josh 10', 'Nate 8', 'A. 7', 'Jessica 7', 'Robert 4', 'Blue 4', 'Tom 4', 'Nick 3', 'State 3', 'Bob 2', 'Flower 2', 'Roy 2', 'Nellie 2', 'Carol 1', 'Kenny 1', 'Jordan 1', 'Troy 1', 'Pete 1', 'Cecelia 1']
# Darryl: ['Andy 571', 'Jim 339', 'Dwight 282', 'Pam 175', 'Michael 138', 'Kevin 133', 'Val 123', 'Erin 77', 'The 68', 'Phyllis 64', 'Gabe 59', 'Nellie 57', 'Toby 50', 'Oscar 49', 'Meredith 45', 'Ryan 32', 'Angela 29', 'Nate 29', 'Robert 27', 'Deangelo 24', 'Clark 24', 'Stanley 23', 'Jada 23', 'Kelly 19', 'Jo 17', 'Holly 16', 'Creed 13', 'Pete 10', 'Calvin 8', 'Todd 7', 'Bob 7', 'Athlead 7', 'Donna 6', 'Asian 4', 'Jessica 4', 'Blue 3', 'Madge 3', 'Roy 3', 'State 1', 'Cathy 1', 'Billy 1', 'Esther 1', 'Hank 1']
# Erin: ['Andy 814', 'Dwight 333', 'Michael 235', 'Pam 220', 'Pete 204', 'Jim 176', 'Gabe 150', 'Kevin 134', 'Darryl 105', 'Oscar 97', 'Nellie 93', 'Robert 83', 'Angela 80', 'Ryan 78', 'The 73', 'Phyllis 71', 'Kelly 51', 'Meredith 48', 'Holly 48', 'Jessica 44', 'Stanley 43', 'Clark 37', 'Irene 35', 'Creed 32', 'Toby 31', 'Deangelo 23', 'David 11', 'Jo 9', 'Todd 9', 'Cathy 9', 'Bob 5', 'Hank 5', 'Donna 4', 'Val 4', 'Jan 4', 'Nate 2', 'Brian 2', 'A. 1', 'Mose 1', 'Kenny 1', 'Roy 1', 'Tom 1', 'Athlead 1']
# Gabe: ['Erin 125', 'Andy 113', 'Dwight 111', 'Jim 99', 'Michael 98', 'Pam 93', 'Darryl 61', 'Toby 56', 'The 39', 'Kelly 36', 'Oscar 34', 'Robert 34', 'Ryan 29', 'Jo 26', 'Kevin 24', 'Val 19', 'Nellie 18', 'Pete 17', 'Phyllis 14', 'Stanley 13', 'Creed 12', 'Holly 12', 'Deangelo 11', 'Meredith 8', 'Angela 8', 'Asian 7', 'Cathy 6', 'Todd 4', 'Bob 4', 'Stephanie 3', 'Tall 2', 'Donna 1', 'Nick 1', 'Jordan 1']
# Donna: ['Michael 155', 'Dwight 29', 'Jim 18', 'Pam 15', 'Kelly 8', 'Andy 4', 'Angela 3', 'Darryl 3', 'Kevin 3', 'Gabe 2', 'The 2', 'Ryan 1', 'Phyllis 1', 'Creed 1', 'Erin 1']
# Meredith: ['Andy 101', 'Pam 92', 'Dwight 85', 'Jim 69', 'Angela 59', 'Michael 53', 'Oscar 48', 'Erin 45', 'Kevin 44', 'Darryl 30', 'Phyllis 29', 'Kelly 19', 'Robert 18', 'Ryan 15', 'Nellie 14', 'Stanley 13', 'Toby 13', 'Clark 13', 'The 12', 'Pete 11', 'Gabe 9', 'Creed 9', 'Holly 3', 'Val 3', 'Brian 3', 'Mose 3', 'Helene 2', 'Jada 2', 'Todd 2', 'Deangelo 2', 'David 2', 'Jan 2', 'Donna 1', 'Jessica 1', 'Cathy 1', 'Jordan 1']
# Toby: ['Michael 114', 'Andy 113', 'Dwight 100', 'Nellie 99', 'Jim 90', 'Pam 53', 'Darryl 45', 'Kevin 45', 'Gabe 44', 'Angela 40', 'Oscar 39', 'Kelly 36', 'Robert 26', 'Meredith 25', 'The 18', 'Erin 16', 'Ryan 16', 'Stanley 16', 'Mose 15', 'Phyllis 12', 'Jo 11', 'Clark 11', 'Pete 11', 'Val 9', 'Holly 6', 'Creed 5', 'Deangelo 2', 'Nate 2', 'Tony 2', 'David 2', 'A. 1', 'Justin 1', 'Jada 1', 'Cathy 1', 'Sasha 1', 'Ravi 1', 'Jordan 1']
# Hank: ['Pam 12', 'Andy 7', 'Michael 7', 'Jim 7', 'Dwight 5', 'Darryl 3', 'Holly 2', 'Kevin 2', 'Phyllis 1', 'Erin 1', 'Jordan 1']
# Jo: ['Michael 84', 'Dwight 61', 'Gabe 33', 'Jim 29', 'Toby 16', 'Kevin 9', 'The 8', 'Holly 7', 'Darryl 7', 'Pam 5', 'Phyllis 4', 'Kelly 4', 'Andy 3', 'Angela 2', 'Erin 2', 'Nellie 2', 'Nick 1', 'Hank 1', 'David 1', 'Deangelo 1', 'Creed 1']
# Nick: ['Dwight 12', 'Jim 5', 'Kevin 3', 'Phyllis 3', 'Ryan 3', 'Stanley 2', 'Kelly 2', 'Gabe 1', 'Angela 1', 'Darryl 1']
# Mose: ['Dwight 23', 'Toby 12', 'Jim 5', 'Zeke 5', 'Angela 4', 'Kevin 4', 'Pam 2', 'Clark 2', 'Darryl 1', 'Jada 1', 'Nate 1']
# Todd: ['Michael 62', 'Dwight 22', 'Andy 14', 'Jim 12', 'Holly 12', 'Kevin 12', 'Darryl 8', 'The 5', 'Stanley 3', 'Kelly 2', 'Creed 2', 'Hank 2', 'Jo 2', 'Pam 1']
# Jan: ['Michael 39', 'Pam 38', 'Dwight 31', 'Andy 18', 'The 6', 'David 5', 'Clark 5', 'Erin 4', 'Jim 3', 'Tom 3', 'Pete 2', 'Angela 2', 'Jordan 1', 'Hunter 1', 'Oscar 1']
# Nate: ['Dwight 47', 'Darryl 32', 'Pam 24', 'Val 12', 'Andy 9', 'Michael 7', 'Jim 7', 'The 5', 'Oscar 4', 'Toby 4', 'Angela 3', 'Jessica 3', 'Erin 2', 'Ravi 2', 'Kevin 2', 'Kelly 1', 'Creed 1', 'Brian 1', 'Zeke 1', 'Nellie 1']
# Holly: ['Michael 512', 'Erin 36', 'Pam 34', 'Dwight 32', 'Kevin 22', 'Jim 20', 'Todd 16', 'Andy 15', 'Phyllis 15', 'The 13', 'Kelly 11', 'Gabe 11', 'Darryl 10', 'Oscar 8', 'Creed 7', 'Ryan 7', 'Stanley 6', 'Meredith 5', 'Toby 4', 'A. 2', 'Tom 2', 'Hank 2', 'Pete 1', 'Angela 1']
# Helene: ['Michael 17', 'Pam 5', 'Dwight 2', 'Jim 2', 'Angela 2', 'Troy 1', 'Meredith 1']
# Robert: ['Andy 340', 'Jim 178', 'Dwight 100', 'Kevin 82', 'Nellie 73', 'Pam 68', 'Erin 62', 'Oscar 46', 'The 46', 'Ryan 29', 'Toby 26', 'Gabe 22', 'Kelly 22', 'Meredith 19', 'Angela 17', 'Phyllis 14', 'David 11', 'Darryl 10', 'Creed 9', 'Stanley 9', 'Bob 6', 'Nate 4', 'Jessica 4', 'Charles 3', 'Jada 2', 'Mose 2', 'Pete 2', 'Blue 1', 'Cathy 1', 'Hank 1', 'Asian 1', 'Clark 1']
# Jada: ['Michael 25', 'Darryl 9', 'Pam 7', 'Oscar 5', 'Andy 4', 'Meredith 4', 'Robert 4', 'Kevin 3', 'Jim 3', 'Creed 1', 'Ryan 1']
# David: ['Andy 83', 'Michael 33', 'Jim 12', 'Robert 11', 'Dwight 10', 'Bob 8', 'Stanley 7', 'Erin 5', 'The 5', 'Phyllis 5', 'Oscar 3', 'Nellie 2', 'Pam 1', 'Jo 1', 'Meredith 1', 'Asian 1', 'Toby 1']
# Tom: ['Jim 24', 'Dwight 3', 'Andy 3']
# Karen: ['Billy 4', 'Michael 2']
# Billy: ['Michael 8', 'The 4', 'Meredith 2', 'Phyllis 2', 'Andy 1', 'Karen 1']
# Deangelo: ['Michael 122', 'Jim 59', 'Dwight 52', 'Kevin 32', 'Pam 31', 'Erin 27', 'Andy 26', 'Kelly 25', 'Darryl 22', 'Ryan 21', 'Oscar 17', 'Gabe 15', 'The 14', 'Phyllis 12', 'Jordan 11', 'Angela 7', 'Toby 7', 'Stanley 6', 'Mose 2']
# Jordan: ['Kelly 9', 'Dwight 9', 'Deangelo 7', 'Pam 5', 'Kevin 3', 'Creed 3', 'Ryan 2', 'Andy 1']
# Nellie: ['Dwight 316', 'Andy 218', 'Jim 154', 'Pam 152', 'Toby 93', 'Erin 90', 'Robert 81', 'Darryl 76', 'Kevin 58', 'The 56', 'Angela 45', 'Oscar 35', 'Stanley 29', 'Phyllis 29', 'Ryan 21', 'Pete 20', 'Meredith 17', 'Creed 17', 'Gabe 14', 'Todd 13', 'Clark 13', 'Cathy 10', 'Mose 6', 'Val 5', 'Nate 4', 'Michael 4', 'Jo 3', 'Irene 3', 'Ravi 3', 'Asian 2', 'David 2', 'Bob 2', 'Roy 2', 'Tony 1', 'Kelly 1', 'Athlead 1', 'Esther 1']
# Val: ['Darryl 93', 'Andy 25', 'Gabe 17', 'Dwight 14', 'Kevin 14', 'Nate 12', 'Nellie 9', 'The 7', 'Jim 6', 'Pam 5', 'Erin 4', 'Toby 4', 'Stanley 3', 'Phyllis 3', 'Jessica 2', 'Kelly 2', 'Oscar 2', 'Angela 2', 'Pete 2', 'Robert 1', 'Kenny 1']
# Cathy: ['Jim 70', 'Dwight 25', 'Pam 15', 'Nellie 9', 'Oscar 6', 'Erin 5', 'Gabe 5', 'Stanley 4', 'Todd 4', 'Andy 3', 'Kevin 2', 'Ryan 1', 'The 1']
# Jessica: ['Andy 77', 'Erin 32', 'Meredith 6', 'Dwight 6', 'Darryl 4', 'Jim 4', 'Toby 3', 'Kenny 3', 'Val 2', 'Kelly 2', 'Phyllis 1', 'Oscar 1', 'Nate 1', 'Kevin 1', 'Robert 1']
# Bob: ['Darryl 9', 'Dwight 2', 'Val 1']
# Irene: ['Erin 28', 'Andy 25', 'Jim 7', 'Nellie 6', 'Jessica 2', 'Robert 1']
# Kenny: ['Andy 9', 'Erin 3', 'Jessica 2', 'Jim 2', 'Pam 1', 'Clark 1']
# Ravi: ['Ryan 18', 'Kelly 14', 'Kevin 6', 'Jim 2', 'Robert 2', 'Phyllis 2', 'Angela 2', 'Pam 1', 'Andy 1']
# Calvin: ['Darryl 7', 'The 1', 'Val 1']
# Jake: ['Dwight 2', 'Meredith 1']
# Sasha: ['Dwight 1', 'Jake 1', 'Meredith 1']
# Pete: ['Erin 185', 'Andy 92', 'Jim 49', 'Kevin 32', 'Pam 32', 'Nellie 30', 'Clark 20', 'Angela 20', 'Dwight 20', 'Darryl 17', 'Toby 17', 'Gabe 15', 'Meredith 9', 'The 8', 'Creed 8', 'Oscar 7', 'Phyllis 4', 'Val 4', 'Jan 2', 'Stanley 2', 'Carol 2', 'Roy 1', 'Tom 1', 'Jordan 1', 'Brian 1']
# Clark: ['Dwight 315', 'Andy 69', 'Jim 62', 'Pam 45', 'Erin 41', 'Pete 34', 'Darryl 31', 'Stanley 30', 'Rolf 13', 'Oscar 11', 'Meredith 9', 'Jan 9', 'Nellie 9', 'The 9', 'Toby 8', 'Athlead 8', 'Esther 8', 'Angela 7', 'Phyllis 6', 'Kevin 6', 'Todd 5', 'Creed 3', 'Zeke 2', 'David 2', 'Mose 2', 'Hunter 1', 'Nate 1', 'Charles 1', 'Gabe 1', 'Brian 1', 'Robert 1']
# Roy: ['Jim 23', 'Darryl 4', 'Pam 3', 'Kenny 2', 'Billy 1']
# Brian: ['Pam 103', 'Jim 16', 'Meredith 9', 'Dwight 6', 'Oscar 6', 'Darryl 5', 'Erin 5', 'Angela 5', 'Andy 3', 'Clark 1']
# Rolf: ['Dwight 20', 'Clark 7', 'Jim 4', 'David 3', 'Pam 2']
# Troy: ['Zeke 1', 'Darryl 1', 'Jim 1']
# Zeke: ['Dwight 30', 'Jim 9', 'Mose 5', 'Oscar 4', 'Clark 2', 'Darryl 1']
# Isaac: ['Pam 8', 'Jim 1']
# Esther: ['Dwight 41', 'Andy 6', 'Jim 4', 'Angela 3', 'Clark 2', 'Nellie 2', 'Zeke 1', 'Pam 1', 'Robert 1', 'Oscar 1', 'David 1']
# Carol: ['Jim 4', 'Pam 2']

# %%
from collections import Counter

def count_connections(connections_dict):
    # New dictionary to store counts
    connections_count_dict = {}

    for name, connections in connections_dict.items():
        # Count the occurrences of each connection
        connection_counts = Counter(connections)
        # Sort the connections by count in descending order
        sorted_counts = sorted(connection_counts.items(), key=lambda x: x[1], reverse=True)
        # Format the count as 'name count'
        formatted_counts = [f"{conn}" for conn, count in sorted_counts]
        # Assign to the new dictionary
        connections_count_dict[name] = formatted_counts

    return connections_count_dict

# Assuming connections_dict is already populated
# connections_dict = find_connections(folder_path, character_names_list) 

# Count the connections
connections_count_dict = count_connections(connections_dict)

# Print the resulting dictionary in descending order of counts
for name, conns in connections_count_dict.items():
    print(f"{name}: {conns}")
# Out:
# Dwight: ['Jim', 'Andy', 'Pam', 'Angela', 'Michael', 'Erin', 'Nellie', 'Clark', 'The', 'Darryl', 'Oscar', 'Kevin', 'Stanley', 'Phyllis', 'Gabe', 'Robert', 'Ryan', 'Kelly', 'Toby', 'David', 'Mose', 'Meredith', 'Jo', 'Nate', 'Esther', 'Cathy', 'Creed', 'Deangelo', 'Donna', 'Holly', 'Jan', 'Todd', 'Pete', 'Zeke', 'Val', 'Rolf', 'Troy', 'Billy', 'Jordan', 'Hank', 'Nick', 'Jessica', 'Athlead', 'Brian', 'Justin', 'Asian', 'Stephanie', 'Jada', 'Helene', 'Flower', 'Dan', 'Madge', 'Carol', 'Sasha', 'Jake', 'Ravi', 'Tom', 'Hunter', 'Charles', 'Josh']
# Jim: ['Dwight', 'Pam', 'Andy', 'Michael', 'Darryl', 'Robert', 'Kevin', 'The', 'Erin', 'Oscar', 'Stanley', 'Phyllis', 'Nellie', 'Angela', 'Ryan', 'Toby', 'Gabe', 'Kelly', 'Meredith', 'Clark', 'Cathy', 'Deangelo', 'Pete', 'Jo', 'Creed', 'Holly', 'David', 'Tom', 'Mose', 'Roy', 'Todd', 'Brian', 'Donna', 'Athlead', 'Jordan', 'Hank', 'Val', 'Jessica', 'Kenny', 'Nate', 'Zeke', 'Irene', 'Esther', 'Nick', 'Blue', 'Ravi', 'Rolf', 'Carol', 'Billy', 'Dan', 'Madge', 'Justin', 'Charles', 'Bob', 'Cecelia', 'State', 'Isaac', 'Jan', 'A.', 'Karen', 'Gerald', 'Elizabeth', 'Gil', 'Asian']
# Pam: ['Jim', 'Dwight', 'Michael', 'Andy', 'Erin', 'Angela', 'Darryl', 'Oscar', 'Nellie', 'Kevin', 'Ryan', 'Phyllis', 'Meredith', 'The', 'Brian', 'Kelly', 'Gabe', 'Toby', 'Robert', 'Stanley', 'Creed', 'Jan', 'Holly', 'Deangelo', 'Clark', 'Pete', 'Cathy', 'Nate', 'David', 'Donna', 'Bob', 'Athlead', 'Todd', 'Jo', 'Helene', 'Hank', 'Roy', 'Jada', 'Val', 'Isaac', 'Carol', 'Tom', 'Jordan', 'A.', 'Cecelia', 'Mose', 'Gil', 'Irene', 'Ravi', 'Blue', 'Troy', 'Zeke', 'State', 'Billy', 'Justin', 'Tony', 'Hunter', 'Rolf', 'Cynthia']
# Stanley: ['Andy', 'Jim', 'Dwight', 'Michael', 'Phyllis', 'Erin', 'Oscar', 'Kevin', 'Pam', 'Meredith', 'Darryl', 'Nellie', 'Angela', 'The', 'Ryan', 'Clark', 'Robert', 'Kelly', 'Creed', 'Toby', 'Pete', 'Gabe', 'Holly', 'Jessica', 'Jada', 'Cathy', 'David', 'Deangelo', 'Kenny', 'Nick', 'Nate', 'Cynthia']
# Kevin: ['Dwight', 'Andy', 'Oscar', 'Angela', 'Michael', 'Jim', 'Pam', 'Darryl', 'Erin', 'Robert', 'The', 'Nellie', 'Ryan', 'Phyllis', 'Creed', 'Toby', 'Pete', 'Meredith', 'Kelly', 'Gabe', 'Stanley', 'Deangelo', 'Val', 'Holly', 'Todd', 'Jo', 'Clark', 'Ravi', 'Mose', 'David', 'A.', 'Jessica', 'Athlead', 'Donna', 'Bob', 'Helene', 'Nick', 'Jada', 'Madge', 'Gerald', 'Charles', 'Cathy', 'Nate', 'Jan']
# Angela: ['Dwight', 'Oscar', 'Pam', 'Kevin', 'Andy', 'Jim', 'Michael', 'Meredith', 'Erin', 'Phyllis', 'The', 'Robert', 'Toby', 'Nellie', 'Darryl', 'Stanley', 'Ryan', 'Kelly', 'Mose', 'Clark', 'Gabe', 'Pete', 'Creed', 'Esther', 'Deangelo', 'Holly', 'Todd', 'Val', 'David', 'Nick', 'State', 'Donna', 'Nate', 'Helene', 'Jo', 'Cathy', 'Gerald', 'Jessica', 'Jan', 'Athlead', 'Brian']
# Phyllis: ['Andy', 'Dwight', 'Michael', 'Jim', 'Pam', 'Erin', 'Stanley', 'Oscar', 'Angela', 'Darryl', 'Kevin', 'Meredith', 'Kelly', 'The', 'Nellie', 'Gabe', 'Holly', 'Creed', 'Robert', 'Ryan', 'Deangelo', 'Toby', 'Val', 'Zeke', 'Bob', 'Clark', 'Jessica', 'David', 'Todd', 'Pete', 'Mose', 'Jo', 'Nick', 'Justin', 'Blue', 'Donna', 'Dan', 'Nate', 'Karen', 'Asian', 'Cathy', 'Elizabeth', 'Athlead', 'Cynthia']
# Creed: ['Pam', 'Michael', 'Andy', 'Jim', 'Dwight', 'Erin', 'Angela', 'Phyllis', 'Kevin', 'Meredith', 'Oscar', 'The', 'Gabe', 'Darryl', 'Stanley', 'Kelly', 'Nellie', 'Toby', 'Clark', 'Ryan', 'Robert', 'Todd', 'Jordan', 'Pete', 'Ravi', 'Holly', 'Jada', 'Jessica', 'Donna', 'Jo', 'Cathy', 'Roy', 'Athlead', 'Esther']
# Oscar: ['Angela', 'Kevin', 'Dwight', 'Andy', 'Jim', 'Pam', 'Michael', 'Erin', 'Darryl', 'Phyllis', 'Meredith', 'Robert', 'The', 'Toby', 'Ryan', 'Kelly', 'Gabe', 'Nellie', 'Stanley', 'Creed', 'Holly', 'Pete', 'David', 'Deangelo', 'Clark', 'Brian', 'Zeke', 'Nate', 'State', 'Gerald', 'Jan', 'Jada', 'Jo', 'Esther', 'Mose', 'Flower', 'Todd', 'Gil', 'Ravi', 'Sasha', 'Bob', 'A.']
# Ryan: ['Kelly', 'Michael', 'Pam', 'Dwight', 'Jim', 'Erin', 'Andy', 'Oscar', 'Kevin', 'The', 'Robert', 'Gabe', 'Ravi', 'Nellie', 'Stanley', 'Angela', 'Deangelo', 'Toby', 'Darryl', 'Meredith', 'Creed', 'Phyllis', 'Holly', 'David', 'Cathy', 'Donna', 'State', 'Justin', 'Jessica', 'Todd', 'Jordan', 'Jo', 'Val', 'Elizabeth', 'Carol', 'Gerald']
# Kelly: ['Ryan', 'Dwight', 'Andy', 'Michael', 'Pam', 'Jim', 'Erin', 'Kevin', 'Gabe', 'Oscar', 'Angela', 'Toby', 'Robert', 'Meredith', 'The', 'Deangelo', 'Phyllis', 'Ravi', 'Darryl', 'Holly', 'Stanley', 'Donna', 'Jessica', 'Creed', 'Jordan', 'Nellie', 'Josh', 'Tom', 'Jo', 'Val', 'Nate', 'Cathy', 'Bob']
# Andy: ['Erin', 'Dwight', 'Darryl', 'Jim', 'Pam', 'Michael', 'Robert', 'Kevin', 'Oscar', 'Nellie', 'Phyllis', 'The', 'Gabe', 'David', 'Stanley', 'Angela', 'Toby', 'Meredith', 'Jessica', 'Pete', 'Kelly', 'Ryan', 'Clark', 'Creed', 'Todd', 'Deangelo', 'Val', 'Kenny', 'Jan', 'Irene', 'Jo', 'Holly', 'Nate', 'Tom', 'Donna', 'Dan', 'Bob', 'Hank', 'Esther', 'Jada', 'Cathy', 'Helene', 'Mose', 'Brian', 'Athlead', 'Madge', 'Blue', 'Jake', 'A.', 'Sasha', 'Ravi', 'State', 'Jordan', 'Asian']
# Michael: ['Holly', 'Pam', 'Dwight', 'Jim', 'Andy', 'Erin', 'Kevin', 'Oscar', 'Darryl', 'Donna', 'Ryan', 'Gabe', 'Toby', 'Phyllis', 'Deangelo', 'The', 'Kelly', 'Stanley', 'Angela', 'Jo', 'Meredith', 'Todd', 'Creed', 'Jan', 'David', 'Jada', 'Billy', 'Helene', 'Hank', 'Josh', 'Nate', 'A.', 'Jessica', 'Robert', 'Blue', 'Tom', 'Nick', 'State', 'Bob', 'Flower', 'Roy', 'Nellie', 'Carol', 'Kenny', 'Jordan', 'Troy', 'Pete', 'Cecelia']
# Darryl: ['Andy', 'Jim', 'Dwight', 'Pam', 'Michael', 'Kevin', 'Val', 'Erin', 'The', 'Phyllis', 'Gabe', 'Nellie', 'Toby', 'Oscar', 'Meredith', 'Ryan', 'Angela', 'Nate', 'Robert', 'Deangelo', 'Clark', 'Stanley', 'Jada', 'Kelly', 'Jo', 'Holly', 'Creed', 'Pete', 'Calvin', 'Todd', 'Bob', 'Athlead', 'Donna', 'Asian', 'Jessica', 'Blue', 'Madge', 'Roy', 'State', 'Cathy', 'Billy', 'Esther', 'Hank']
# Erin: ['Andy', 'Dwight', 'Michael', 'Pam', 'Pete', 'Jim', 'Gabe', 'Kevin', 'Darryl', 'Oscar', 'Nellie', 'Robert', 'Angela', 'Ryan', 'The', 'Phyllis', 'Kelly', 'Meredith', 'Holly', 'Jessica', 'Stanley', 'Clark', 'Irene', 'Creed', 'Toby', 'Deangelo', 'David', 'Jo', 'Todd', 'Cathy', 'Bob', 'Hank', 'Donna', 'Val', 'Jan', 'Nate', 'Brian', 'A.', 'Mose', 'Kenny', 'Roy', 'Tom', 'Athlead']
# Gabe: ['Erin', 'Andy', 'Dwight', 'Jim', 'Michael', 'Pam', 'Darryl', 'Toby', 'The', 'Kelly', 'Oscar', 'Robert', 'Ryan', 'Jo', 'Kevin', 'Val', 'Nellie', 'Pete', 'Phyllis', 'Stanley', 'Creed', 'Holly', 'Deangelo', 'Meredith', 'Angela', 'Asian', 'Cathy', 'Todd', 'Bob', 'Stephanie', 'Tall', 'Donna', 'Nick', 'Jordan']
# Donna: ['Michael', 'Dwight', 'Jim', 'Pam', 'Kelly', 'Andy', 'Angela', 'Darryl', 'Kevin', 'Gabe', 'The', 'Ryan', 'Phyllis', 'Creed', 'Erin']
# Meredith: ['Andy', 'Pam', 'Dwight', 'Jim', 'Angela', 'Michael', 'Oscar', 'Erin', 'Kevin', 'Darryl', 'Phyllis', 'Kelly', 'Robert', 'Ryan', 'Nellie', 'Stanley', 'Toby', 'Clark', 'The', 'Pete', 'Gabe', 'Creed', 'Holly', 'Val', 'Brian', 'Mose', 'Helene', 'Jada', 'Todd', 'Deangelo', 'David', 'Jan', 'Donna', 'Jessica', 'Cathy', 'Jordan']
# Toby: ['Michael', 'Andy', 'Dwight', 'Nellie', 'Jim', 'Pam', 'Darryl', 'Kevin', 'Gabe', 'Angela', 'Oscar', 'Kelly', 'Robert', 'Meredith', 'The', 'Erin', 'Ryan', 'Stanley', 'Mose', 'Phyllis', 'Jo', 'Clark', 'Pete', 'Val', 'Holly', 'Creed', 'Deangelo', 'Nate', 'Tony', 'David', 'A.', 'Justin', 'Jada', 'Cathy', 'Sasha', 'Ravi', 'Jordan']
# Hank: ['Pam', 'Andy', 'Michael', 'Jim', 'Dwight', 'Darryl', 'Holly', 'Kevin', 'Phyllis', 'Erin', 'Jordan']
# Jo: ['Michael', 'Dwight', 'Gabe', 'Jim', 'Toby', 'Kevin', 'The', 'Holly', 'Darryl', 'Pam', 'Phyllis', 'Kelly', 'Andy', 'Angela', 'Erin', 'Nellie', 'Nick', 'Hank', 'David', 'Deangelo', 'Creed']
# Nick: ['Dwight', 'Jim', 'Kevin', 'Phyllis', 'Ryan', 'Stanley', 'Kelly', 'Gabe', 'Angela', 'Darryl']
# Mose: ['Dwight', 'Toby', 'Jim', 'Zeke', 'Angela', 'Kevin', 'Pam', 'Clark', 'Darryl', 'Jada', 'Nate']
# Todd: ['Michael', 'Dwight', 'Andy', 'Jim', 'Holly', 'Kevin', 'Darryl', 'The', 'Stanley', 'Kelly', 'Creed', 'Hank', 'Jo', 'Pam']
# Jan: ['Michael', 'Pam', 'Dwight', 'Andy', 'The', 'David', 'Clark', 'Erin', 'Jim', 'Tom', 'Pete', 'Angela', 'Jordan', 'Hunter', 'Oscar']
# Nate: ['Dwight', 'Darryl', 'Pam', 'Val', 'Andy', 'Michael', 'Jim', 'The', 'Oscar', 'Toby', 'Angela', 'Jessica', 'Erin', 'Ravi', 'Kevin', 'Kelly', 'Creed', 'Brian', 'Zeke', 'Nellie']
# Holly: ['Michael', 'Erin', 'Pam', 'Dwight', 'Kevin', 'Jim', 'Todd', 'Andy', 'Phyllis', 'The', 'Kelly', 'Gabe', 'Darryl', 'Oscar', 'Creed', 'Ryan', 'Stanley', 'Meredith', 'Toby', 'A.', 'Tom', 'Hank', 'Pete', 'Angela']
# Helene: ['Michael', 'Pam', 'Dwight', 'Jim', 'Angela', 'Troy', 'Meredith']
# Robert: ['Andy', 'Jim', 'Dwight', 'Kevin', 'Nellie', 'Pam', 'Erin', 'Oscar', 'The', 'Ryan', 'Toby', 'Gabe', 'Kelly', 'Meredith', 'Angela', 'Phyllis', 'David', 'Darryl', 'Creed', 'Stanley', 'Bob', 'Nate', 'Jessica', 'Charles', 'Jada', 'Mose', 'Pete', 'Blue', 'Cathy', 'Hank', 'Asian', 'Clark']
# Jada: ['Michael', 'Darryl', 'Pam', 'Oscar', 'Andy', 'Meredith', 'Robert', 'Kevin', 'Jim', 'Creed', 'Ryan']
# David: ['Andy', 'Michael', 'Jim', 'Robert', 'Dwight', 'Bob', 'Stanley', 'Erin', 'The', 'Phyllis', 'Oscar', 'Nellie', 'Pam', 'Jo', 'Meredith', 'Asian', 'Toby']
# Tom: ['Jim', 'Dwight', 'Andy']
# Karen: ['Billy', 'Michael']
# Billy: ['Michael', 'The', 'Meredith', 'Phyllis', 'Andy', 'Karen']
# Deangelo: ['Michael', 'Jim', 'Dwight', 'Kevin', 'Pam', 'Erin', 'Andy', 'Kelly', 'Darryl', 'Ryan', 'Oscar', 'Gabe', 'The', 'Phyllis', 'Jordan', 'Angela', 'Toby', 'Stanley', 'Mose']
# Jordan: ['Kelly', 'Dwight', 'Deangelo', 'Pam', 'Kevin', 'Creed', 'Ryan', 'Andy']
# Nellie: ['Dwight', 'Andy', 'Jim', 'Pam', 'Toby', 'Erin', 'Robert', 'Darryl', 'Kevin', 'The', 'Angela', 'Oscar', 'Stanley', 'Phyllis', 'Ryan', 'Pete', 'Meredith', 'Creed', 'Gabe', 'Todd', 'Clark', 'Cathy', 'Mose', 'Val', 'Nate', 'Michael', 'Jo', 'Irene', 'Ravi', 'Asian', 'David', 'Bob', 'Roy', 'Tony', 'Kelly', 'Athlead', 'Esther']
# Val: ['Darryl', 'Andy', 'Gabe', 'Dwight', 'Kevin', 'Nate', 'Nellie', 'The', 'Jim', 'Pam', 'Erin', 'Toby', 'Stanley', 'Phyllis', 'Jessica', 'Kelly', 'Oscar', 'Angela', 'Pete', 'Robert', 'Kenny']
# Cathy: ['Jim', 'Dwight', 'Pam', 'Nellie', 'Oscar', 'Erin', 'Gabe', 'Stanley', 'Todd', 'Andy', 'Kevin', 'Ryan', 'The']
# Jessica: ['Andy', 'Erin', 'Meredith', 'Dwight', 'Darryl', 'Jim', 'Toby', 'Kenny', 'Val', 'Kelly', 'Phyllis', 'Oscar', 'Nate', 'Kevin', 'Robert']
# Bob: ['Darryl', 'Dwight', 'Val']
# Irene: ['Erin', 'Andy', 'Jim', 'Nellie', 'Jessica', 'Robert']
# Kenny: ['Andy', 'Erin', 'Jessica', 'Jim', 'Pam', 'Clark']
# Ravi: ['Ryan', 'Kelly', 'Kevin', 'Jim', 'Robert', 'Phyllis', 'Angela', 'Pam', 'Andy']
# Calvin: ['Darryl', 'The', 'Val']
# Jake: ['Dwight', 'Meredith']
# Sasha: ['Dwight', 'Jake', 'Meredith']
# Pete: ['Erin', 'Andy', 'Jim', 'Kevin', 'Pam', 'Nellie', 'Clark', 'Angela', 'Dwight', 'Darryl', 'Toby', 'Gabe', 'Meredith', 'The', 'Creed', 'Oscar', 'Phyllis', 'Val', 'Jan', 'Stanley', 'Carol', 'Roy', 'Tom', 'Jordan', 'Brian']
# Clark: ['Dwight', 'Andy', 'Jim', 'Pam', 'Erin', 'Pete', 'Darryl', 'Stanley', 'Rolf', 'Oscar', 'Meredith', 'Jan', 'Nellie', 'The', 'Toby', 'Athlead', 'Esther', 'Angela', 'Phyllis', 'Kevin', 'Todd', 'Creed', 'Zeke', 'David', 'Mose', 'Hunter', 'Nate', 'Charles', 'Gabe', 'Brian', 'Robert']
# Roy: ['Jim', 'Darryl', 'Pam', 'Kenny', 'Billy']
# Brian: ['Pam', 'Jim', 'Meredith', 'Dwight', 'Oscar', 'Darryl', 'Erin', 'Angela', 'Andy', 'Clark']
# Rolf: ['Dwight', 'Clark', 'Jim', 'David', 'Pam']
# Troy: ['Zeke', 'Darryl', 'Jim']
# Zeke: ['Dwight', 'Jim', 'Mose', 'Oscar', 'Clark', 'Darryl']
# Isaac: ['Pam', 'Jim']
# Esther: ['Dwight', 'Andy', 'Jim', 'Angela', 'Clark', 'Nellie', 'Zeke', 'Pam', 'Robert', 'Oscar', 'David']
# Carol: ['Jim', 'Pam']

# %%
import networkx as nx
import matplotlib.pyplot as plt
from collections import Counter

# Function to count connections and return only the top 5
def count_top_connections(connections_dict):
    top_connections_dict = {}
    for name, connections in connections_dict.items():
        connection_counts = Counter(connections)
        sorted_counts = sorted(connection_counts.items(), key=lambda x: x[1], reverse=True)
        top_connections_dict[name] = [conn for conn, count in sorted_counts[:5]]
    return top_connections_dict

# Function to create and draw the graph
def draw_graph(top_connections_dict):
    G = nx.Graph()
    for name, connections in top_connections_dict.items():
        for conn in connections:
            G.add_edge(name, conn)

    plt.figure(figsize=(12, 8))
    nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_color='gray')
    plt.title("Character Connection Graph")
    plt.show()

# Assuming connections_dict is already populated
# connections_dict = find_connections(folder_path, character_names_list) 

# Get the top 5 connections for each character
top_connections_dict = count_top_connections(connections_dict)

# Draw the graph
draw_graph(top_connections_dict)
